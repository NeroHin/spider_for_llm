# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

def fetch_faq_and_categories():
    url = 'https://www.cathaybk.com.tw/cathaybk/personal/contact/help/faq/'
    response = requests.get(url)
    response.raise_for_status()  # 檢查請求是否成功

    soup = BeautifulSoup(response.text, 'html.parser')

    # 先提取所有類別的 id 和內容
    categories = {}
    for checkbox in soup.find_all(class_='cubre-a-checkbox__input'):
        category_id = checkbox['id']
        label = soup.find('label', {'for': category_id})
        if label:
            categories[category_id] = label.text.strip()
    
    # 爬取每個 class="cubre-m-collapse__item" 的元素
    for item in tqdm(soup.find_all(class_='cubre-m-collapse__item')):
        data_item_filter = item['data-item-filter'].split(', ')
        
        for categories_name in data_item_filter:
            category_names = [categories.get(category_id, 'Unknown Category')  for category_id in categories_name.split(',')]
            # remove'不限' or ' 不限' or '不限 '
            category_names = [category_name for category_name in category_names if category_name != '不限' and category_name != ' 不限' and category_name != '不限 ']
            # remove the duplicate category name
            categories_name = list(set(category_names))
       
        title = item.find(class_='cubre-m-collapse__title').text.strip()
        text_content = item.find(class_='cubre-o-textContent').text.strip()
        text_content = '\n'.join([line for line in text_content.split('\n') if line.strip()])


        # 匹配輸出每個元素的類別、標題和文本內容
        print(f'Categories: {", ".join(category_names)}')
        print(f'Title: {title}')
        print(f'Text Content: {text_content}')
        print('-' * 50)  # 輸出一個分隔線以區分不同的元素
        
        # save to .csv
        with open('cathaybk_faq.csv', 'a', encoding='utf-8') as f:
            f.write(f'Categories: {", ".join(category_names)}\n')
            f.write(f'Title: {title}\n')
            f.write(f'Text Content: {text_content}\n')
            f.write('-' * 50 + '\n')
if __name__ == "__main__":
    fetch_faq_and_categories()
# Out:
# 100%|██████████| 634/634 [00:00<00:00, 27482.88it/s]
# Categories: 子帳戶
# Title: 子帳戶的申請資格是什麼？
# Text Content: 加開子帳戶方式如下：
# 具備臺幣活期儲蓄存款、綜合活期儲蓄存款、國泰世華數位存款帳戶(3-1類、2類、1-1類)，或KOKO數位存款帳戶(3-1類、2類、1-2類及1-1類)能開啟子帳戶，開啟方式說明：
# 登入個人網銀App，點選【臺幣總額】 > 選擇母帳戶右方更多功能 >【 新增子帳戶】，每一母帳戶下共可加開５組子帳戶。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶可透過什麼管道申請？
# Text Content: 開立子帳戶方式如下：
# 登入網路銀行App，點選【臺幣總額】> 選擇母帳戶右方更多功能 >【新增子帳戶】> 即可依畫面步驟進行操作。
# ※提醒你，開立通路僅限網路銀行App。
# --------------------------------------------------
# Categories: 手機/Email共用, 手機/Email共用
# Title: 為何我無法與他人共用手機門號/電子郵件？
# Text Content: 本行會透過您留存於本行的手機門號/Email，通知您與本行往來之所有個人帳務資訊與個人權益。請勿與其他用戶使用相同的手機門號/Email，以避免您的個人帳務隱私外洩並保障您的帳戶安全。
# 若您有家戶共用手機門號/電子郵件需求，請備妥您與手機門號/電子郵件共用者的關係證明文件正本(身分證、居留證、戶口名簿/戶籍謄本、法律判決書)，至CUBE網銀或分行臨櫃辦理手機/Email共用註記。目前僅開放申請特定關係對象共用手機門號/電子郵件，包含血親三等親內、姻親二等親內、法定代理人、或監護人之關係。一般客戶共用申請成功後，共用效期為期三年、未成年則至成年。
# *CUBE網銀申請路徑：[申請設定]→[資料異動]→[修改個人資料]→共用註記申請/進度查詢
# *血親三等親內、姻親二等親內關係說明如下:
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 我已申請非約定轉帳服務，為何還是無法於CUBE App轉帳？
# Text Content: CUBE  App「非約定轉帳」功能，需搭配「人臉辨識」或「交易認證碼」(原隨身密碼)方可使用。您可於「設定」-「交易驗證方式」進行設定。
# 因新版CUBE  App調整「交易認證碼」(原隨身密碼)申請原則，若您之前已於臨櫃申請「交易認證碼」，但未開通「非約定轉帳」功能，您將無法使用非約定轉帳功能，煩請您由「帳戶總覽」-「 臺幣」頁面右上方進入「帳戶資訊」，在臺幣帳戶資訊頁可開啟非約定轉帳的設定。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶是什麼？
# Text Content: 子帳戶的介紹如下：
# 為提供客戶更完善的交易服務，於網路銀行App新增「子帳戶」功能，提供客戶分戶管理之服務，以提高客戶服務品質。
# --------------------------------------------------
# Categories: 帳戶安全
# Title: CUBE App有那些保障措施保障我的帳戶使用安全?
# Text Content: 為保障行動銀行的使用安全，國泰世華行動銀行提供您 24 小時不間斷的防護。包含：
# 信用卡安全鎖 臨時找不到信用卡可自行透過 APP 鎖卡，主動保障卡片安全
# 交易警示推播 APP 即時推播安全警示通知，主動保護交易安全
# 人臉非約轉 轉帳驗證用人臉，比手動輸入密碼更安全，手機有前鏡頭就能使用
# 安全健檢專區 透過登入、交易及系統等三個層面8大項目即時檢測您的帳戶安全狀態
# FIDO 國際級驗證 以生物辨識登入 APP 快速又安全，免手動輸入密碼更安全
# 登入紀錄 可查詢每筆登入紀錄，確保皆為本人登入更安心
# 瞭解更多安心罩功能
# 1) 信用卡安全鎖
# 首頁點擊進入信用卡完整資訊
# 在頁面最下方點擊卡片，進入 “我的信用卡”
#  在“卡片安全鎖”旁點擊“我要鎖卡”
#  卡片鎖定按鈕向右滑，即可開啟卡片安全鎖
#  若需解鎖，卡片鎖定按鈕再次向右滑，可解鎖
# 信用卡安全鎖可以幫助您鎖定卡片。卡片鎖定後，將無法進行刷卡交易 (含行動支付)、預借現金、信用卡代繳費用。但已分期款、年費、離線交易 (例如: 機上消費、部分飯店 / 旅行社預刷卡等) 則不受限制仍可交易。
# 啟用卡片安全鎖將無法參與部分信用卡回饋活動。
# 鎖定效期為 30 天，期滿將自動解鎖 ; 若您想進行誇卡交易可隨時進行異動。若卡片遺失，請聯絡客服進行掛失、補發。
# 當您完成卡片鎖定，本行會寄通知信至您留存於本行的電子信箱。
# 2) 交易警示推播
# 點擊“更多”後，選取“設定”
# 選擇「推播通知設定」
#  開啟您需要的推播通知確保帳戶資訊不漏接”
# 3) 以人臉辨識做為轉帳驗證
# 點擊“更多”後，選取“設定”
# 選擇「轉帳驗證方式設定」
# 選擇「人臉辨識驗證」
#  啟用成功可開始使用人臉辨識進行非約定轉帳
# 4)安全健檢專區
# 登入CUBE App，點擊右下角 “更多“，點擊”尚未進行安全檢測”  立即檢測
# 顯示安全健檢進度，並依畫面指示逐項完成設定
# 安全健檢專區 透過登入、交易及系統等三個層面8大項目即時檢測您的帳戶安全狀態
# 5) FIDO 登入安全性升級
# CUBE App快速登入 (生物特徵辨識) 運用國際聯盟 FIDO 所建立的國際標準，以非對稱金鑰技術為基礎之技術，提供更簡單與具安全性的驗證方式。安全性升級後，一人僅能使用一個裝置進行快速登入 (生物特徵辨識)，其他裝置將改為使用代號密碼登入。
# 登入方式將由手機原生支援的生物辨識取代，原先註冊的人臉辨識服務將應用於非約定轉帳交易。
# 點擊“更多”後，選取“設定”
# 選擇「登入方式設定」
# 選擇「生物辨識登入」
# 升級登入安全性，點擊 "馬上升級"
# 同意服務條款
# 手機認證
# 生物辨識認證
# 設定成功，您可使用生物辨識快速安全登入
# 6) 登入紀錄
# 點擊 "更多"，進入“安全健檢”區
# 點擊 "查看登入紀錄”
# 可查看網路銀行App與網路銀行的登入紀錄
# --------------------------------------------------
# Categories: 手機/Email共用, 手機/Email共用
# Title: 若有特定共用需求能與哪些人共用手機門號/電子郵件？如何申請？
# Text Content: 目前僅開放申請特定關係對象共用手機門號/電子郵件，包含血親三等親內、姻親二等親內、法定代理人、或監護人之關係。請確認共用對象符合資格，備妥關係證明文件正本(身分證、居留證、戶口名簿/戶籍謄本、法律判決書)，至CUBE網銀或分行臨櫃辦理，一般客戶共用申請成功後，共用效期為期三年、未成年則至成年。
# *CUBE網銀申請路徑：[申請設定]→[資料異動]→[修改個人資料]→共用註記申請/進度查詢
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: CUBE App能提供那些功能與服務？
# Text Content: CUBE App提供您多元金融服務如下：
# 帳戶服務：台外幣帳戶餘額/交易明細查詢、約定/非約轉帳。
# 外匯服務：外幣買賣、利匯率查詢、匯率換算。
# 基金服務：基金損益/資訊查詢、基金申購、基金贖回。
# 信用卡服務：帳單/消費明細/點數查詢、帳戶/超商繳費。
# 繳費稅：電信費、水電費、路邊停車費、各項稅款。
# 生活服務：推播通知、服務據點查詢、分行櫃檯預約取號。
# 註：部分服務會需要臨櫃申辦或開通權限才能提供。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我要去哪裡下載CUBE App呢？
# Text Content: 商店搜尋下載
# Android手機用戶可至Google Play商店，iOS手機用戶可至APP Store搜尋「國泰世華CUBE網銀」下載。
# 掃描QRCODE下載
# 您可利用手機掃描以下QRCODE下載。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: CUBE App非約定轉帳的額度限制為何？
# Text Content: 預設限額：每筆新臺幣5萬、每日新臺幣10萬元、每月新臺幣20萬元。
# 自設限額：您可持身分證正本與帳戶原留印鑑至分行申請調整非約轉額度，每筆/每日新臺幣1~50萬、每月新臺幣1~100萬。自設限額須以萬元為單位。
# 此「非約定帳戶轉帳」限額計入網路銀行、CUBE App合併計算。
# 網路銀行及CUBE App之繳費、繳稅交易金額不計入此非約轉額度。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我需要符合甚麼資格才能使用CUBE App服務？
# Text Content: 只要您擁有本行有效帳戶或信用卡，並申請「網銀密碼」，即可使用CUBE App服務。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我擁有多個國泰世華銀行帳戶或多張信用卡，需要逐個帳戶或逐張卡申請嗎？
# Text Content: 不需要，CUBE App採個人歸戶，只要申辦一次即可查詢/使用個人名下所有帳戶或信用卡服務。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我已是網路銀行用戶，能直接使用CUBE App服務嗎？
# Text Content: 可以，您可使用網路銀行之「網銀密碼」與「用戶代號」登入CUBE App享受服務。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 任何型號的手機都能使用CUBE App服務嗎？
# Text Content: 支援iPhone iOS 13.0(含)以上手機版本；標準Google 官方公佈的支援裝置，Android OS 7.0(含)以上手機版本。
# 註：請使用系統未經破解的手機，並透過官方軟體商店下載CUBE App及安裝防毒軟體，以降低交易風險及保護個人資訊安全。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我已是國泰世華銀行存戶，該如何申請使用CUBE App？
# Text Content: 請先申請網銀密碼後登入CUBE App、CUBE網銀。
# 本行成年存戶請用以下方法申請：
# 分行申請：持身分證正本與帳戶原留印鑑，親洽任一分行即可申請。
# ATM申請：持國泰世華銀行所發行之晶片金融卡，透過國泰世華銀行ATM申請。
# CUBE  App申請_視訊客服：透過國泰世華CUBE  App，在登入頁面選擇【忘記代號/密碼】→ 選擇【視訊客服】進行簡訊OTP驗證及身分證資料驗證，即可進入視訊服務申請。
# 本行未成年存戶請偕同法定代理人雙方/監護人於營業時間親洽任一分行申請，並攜帶下列正本資料：
# 未成年人-【戶口名簿/戶籍謄本/身分證正本】+【第二身分證件】+【原留印鑑】。
# 法定代理人雙方-【身分證正本】+【第二身分證件】。
# 單親法定代理人/監護人-【身分證正本】+【第二身分證件】+ 提供載明監護權歸屬的文件，如：戶口名簿或戶籍謄本或法院判決書/裁定書等文件正本。
# 如法定代理人一方不克前來，需另徵提【委託人身分證正本】+【第二身分證件】+【辦理存款業務同意書】 。
# 一旦申請或重設，須於指定時效內進行設定，始完成啟用流程。
# 效期說明：密碼單為15日（須以密碼單內之指定用戶代號及網銀密碼登入CUBE  App或CUBE 網路銀行變更啟用）；簡訊連結為簡訊發送後72小時內（設定後始生效力）。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我擁有國泰世華銀行信用卡，該如何申請使用CUBE App？
# Text Content: 請先申請網銀密碼後登入CUBE App、CUBE網銀。
# 本行正卡卡友（不含商務卡）請用以下方法申請：
# CUBE  App、CUBE 網路銀行申請：於簡訊OTP驗證後自行設定用戶代號及網銀密碼。
# 本行智能客服：進入智能客服對話並選擇【信用卡戶】，輸入身分證字號並完成簡訊OTP驗證後，即可設定用戶代號及網銀密碼。
# 備註：信用卡理網銀碼服務範圍僅限信用卡相關查詢功能，若您同時為本行存款戶，欲使用帳務功能，請參閱存戶申請網銀密碼方式，體驗完整的數位理財服務。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 為何在google play無法下載安裝CUBE App？
# Text Content: 親愛的用戶您好，若您遭遇無法順利下載或安裝卡住情況，是由於Google Play快取異常導致
# 建議您參考Google官方的異常排除步驟
# ‌
# https://support.google.com/googleplay/answer/7513003?hl=zh-Hant&ref_topic=1046719&visit_id=637748806413572636-3883880234&rd=1
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 首次登入CUBE App，我需要做哪些事？
# Text Content: 首次登入教學
# --------------------------------------------------
# Categories: 大額換匯
# Title: 請問國泰世華銀行已經開辦線上等值新臺幣五十萬以上的換匯了嗎?
# Text Content: 是的，為提升國泰世華銀行數位服務功能，本行已於2022/3/8開辦線上等值新臺幣五十萬以上之換匯服務，目前僅限於CUBE App下載【國泰世華憑證】後方可交易（限換匯交易）。
# --------------------------------------------------
# Categories: 大額換匯
# Title: 請問國泰世華銀行CUBE App開辦的線上等值新臺幣五十萬以上換匯，有限什麼身份或資格才能辦理？
# Text Content: 本服務限本國成年自然人及持中華民國居留證有效期間一年期以上之成年自然人，如為數位存款帳戶，限持數位存款一類及二類帳戶才能辦理。
# --------------------------------------------------
# Categories: 大額換匯
# Title: 請問國泰世華銀行線上等值新臺幣五十萬以上的換匯服務有限交易時間嗎？服務流程是什麼?
# Text Content: 線上等值新臺幣五十萬以上之換匯服務限每營業AM 09:00~PM03:30於CUBE App辦理，服務流程請
# ‌
# 按此
# 。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 「網銀密碼」或「用戶代號」的設定規則為何？
# Text Content: 基於使用網路銀行的安全性，您的用戶代號與網銀密碼必須依照下列規則進行設定：
# 用戶代號：6至12位英文與數字混合代號。
# 網銀密碼：6至16位英文與數字混合密碼。
# 兩者規則皆為英文最少二位、數字最少一位、英文字大小寫視為不同；設定時請勿使用生日、電話、身分證字號、連續升降冪英數字、相同數字或具規則性排列等容易被有心人士猜到的數字。同時為提高安全性，您無法將用戶代號與網銀密碼設定為相同之數字。
# --------------------------------------------------
# Categories: 大額換匯
# Title: 請問什麼是國泰世華憑證(軟體憑證)?
# Text Content: 依據指定銀行受理顧客透過電子或通訊設備辦理外匯業務作業要點的規定，如存戶要在線上辦理涉及新臺幣達50萬以上之換匯交易時，應確認客戶申報書電子簽章相符後辦理。
# 本憑證會由客戶下載在交易的手機中，下載時需設定一組憑證的密碼，存戶在執行大額交易時需輸入憑證密碼以進行電子簽章。
# --------------------------------------------------
# Categories: 大額換匯
# Title: 國泰世華憑證要如何申請?
# Text Content: 當您在CUBE App執行換匯時，若當日在國泰世華銀行所有通路累積換匯金額（台幣換外幣／外幣換台幣分開計）大於等於50萬時，我們會在交易流程中導引您下載國泰世華銀行憑證。
# --------------------------------------------------
# Categories: 大額換匯
# Title: 國泰世華銀行的憑證要申請前有需要準備什麼嗎?
# Text Content: 申請國泰世華銀行憑證時，需要透過【人臉】或【交易認證碼】進行安全驗證，請先確認您是至少已持有其中一種驗身工具。
# --------------------------------------------------
# Categories: 大額換匯
# Title: 申請國泰世華憑證要收費嗎？
# Text Content: 目前優惠免收憑證費用，歡迎多加利用。
# --------------------------------------------------
# Categories: 大額換匯
# Title: 請問「預約換匯服務」也可以進行等值新臺幣五十萬以上之換匯交易嗎?
# Text Content: 目前線上等值新臺幣五十萬以上的換匯服務僅限於即時換匯交易，預約換匯服務不適用。
# --------------------------------------------------
# Categories: 裝置綁定
# Title: 我要怎麼完成裝置綁定？
# Text Content: 裝置綁定操作流程如下：
# 登入CUBE App，點選右下角【更多】
# 點選【交易設定】>【裝置綁定】
#  確認WIFI狀態及SIM卡電信業者是否適用
# 確認個資與服務條款
# 手機OTP驗證(驗證碼將傳送至本行留存的手機號碼)
# 綁定成功
# 將會收成功到通知信及簡訊
# --------------------------------------------------
# Categories: 裝置綁定
# Title: 「裝置綁定」的好處是什麼？
# Text Content: 您與本行約定可使用的行動裝置，以防止他人透過其他設備操作您的帳戶。另外，裝置綁定可取代手機提款前人臉或交易認證碼驗證，快速取得手機提款序號，省時又安全
# --------------------------------------------------
# Categories: 裝置綁定
# Title: 我換手機了，要怎麼變更裝置綁定？
# Text Content: 依照前述裝置綁定步驟進到頁面後，點選「重新綁定目前裝置」即可開始綁定流程
# --------------------------------------------------
# Categories: 裝置綁定
# Title: 我不想綁定裝置了，可以解除嗎？
# Text Content: 為維護您的帳戶安全，尚不提供裝置綁定解除服務
# --------------------------------------------------
# Categories: 裝置綁定
# Title: 我可以同時綁定兩個裝置嗎？
# Text Content: 為維護您的帳戶安全，每個身分證字號僅限綁定一個裝置喔! 如有需要，您可以依上述變更裝置步驟綁定新的裝置
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 「網銀密碼」或「用戶代號」錯誤次數的上限為幾次？是否與網路銀行合計？
# Text Content: 「網銀密碼」與「用戶代號」錯誤次數上限4次，網路銀行與CUBE App合併計算。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我忘記「網銀密碼」或「用戶代號」，該如何重新申請？
# Text Content: 本行成年存戶請用以下方法申請重設：
# 分行申請：持身分證正本與帳戶原留印鑑，親洽任一分行即可申請。
# ATM申請：持國泰世華銀行所發行之晶片金融卡，透過國泰世華銀行ATM申請重設。
# CUBE App申請_視訊客服：透過國泰世華CUBE  App，在登入頁面選擇【忘記代號/密碼】→ 選擇【視訊客服】進行簡訊OTP驗證及身分證資料驗證，即可進入視訊服務申請重設。
# CUBE App申請_人臉辨識服務：如已註冊過人臉辨識，透過國泰世華CUBE  App，在登入頁面選擇【忘記代號/密碼】→ 選擇【人臉辨識】進行簡訊OTP驗證及人臉驗證，即可申請重設。
# 本行未成年存戶請偕同法定代理人雙方/監護人於營業時間親洽任一分行申請，並攜帶下列正本資料：
# 未成年人-【戶口名簿/戶籍謄本/身分證正本】+【第二身分證件】+【原留印鑑】。
# 法定代理人雙方-【身分證正本】+【第二身分證件】。
# 單親法定代理人/監護人-【身分證正本】+【第二身分證件】+ 提供載明監護權歸屬的文件，如：戶口名簿或戶籍謄本或法院判決書/裁定書等文件正本。
# 如法定代理人一方不克前來，需另徵提【委託人身分證正本】+【第二身分證件】+【辦理存款業務同意書】 。
# 一旦申請或重設，須於指定時效內進行設定，始完成啟用流程。
# 效期說明：密碼單為15日（須以密碼單內之指定用戶代號及網銀密碼登入CUBE  App或CUBE 網路銀行變更啟用）；簡訊連結為簡訊發送後72小時內（設定後始生效力）。
# 本行正卡卡友（不含商務卡）請用以下方法申請：
# CUBE App、CUBE網路銀行申請：於簡訊OTP驗證後自行設定用戶代號及網銀密碼。
# 本行智能客服：進入智能客服對話並選擇【信用卡戶】，輸入身分證字號並完成簡訊OTP驗證後，即可設定用戶代號及網銀密碼。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我只有一組「網銀密碼」與「用戶代號」，可以在多台行動裝置使用CUBE App嗎？
# Text Content: 可以，您可於多台行動裝置使用CUBE App，惟不得同時使用。但「交易認證碼」與「FIDO安全認證」僅限綁定於一台裝置上，不可綁定於多台裝置，故如重新申請或於其他行動裝置啟用「交易認證碼」及「FIDO安全認證」時，原綁定行動裝置之「交易認證碼」及「FIDO安全認證」將立即失效。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我可以同時登入CUBE App與網路銀行嗎？
# Text Content: 不行，系統將會偵測您的登入狀態，若發現重複登入將會提示您，請您將前一次登入進行登出。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: CUBE App自動登出的時間限制為何？
# Text Content: CUBE App自動登出時間與網路銀行相同，登入後未進行任何操作達600秒，系統將自動登出。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我可以透過那些方式登入CUBE App？如何設定快速登入？
# Text Content: 1) 設定生物辨識 (人臉 / 指紋) 登入
# CUBE App 快速登入 (生物特徵辨識) 運用國際聯盟 FIDO 所建立的國際標準，以非對稱金鑰技術為基礎之技術，提供更簡單與具安全性的驗證方式。安全性升級後，一人僅能使用一個裝置進行快速登入 (生物特徵辨識)，其他裝置將改為使用代號密碼登入。登入方式將由手機原生支援的生物辨識取代，原先註冊的人臉辨識服務將應用於非約定轉帳交易。
# 點擊“更多”後，選取“設定”
# 選擇「登入方式設定」
#  選擇「生物辨識登入」
#  升級登入安全性，點擊 "馬上升級"
#  同意服務條款
#  手機認證
#  生物辨識認證
#  設定成功，您可使用生物辨識快速安全登入
# 安全性升級後，有什麼不同?
# 一人僅能使用一個裝置進行快速登入 (生物特徵辨識)，其他裝置將改為使用代號密碼登入。
# 登入方式將由手機原生支援的生物辨識取代，原先註冊的人臉辨識服務將應用於非約定轉帳交易。
# 2) 設定手勢登入
# 點擊“更多”後，選取“設定”
# 選擇「登入方式設定」
#  選擇「生物辨識登入」
#  選擇「生物辨識登入」
#  選擇「生物辨識登入」
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我可以開啟那些權限讓我的CUBE App更好用?
# Text Content: 交易便捷服務，【請點此】
# 交易安全防護，【請點此】
# --------------------------------------------------
# Categories: 帳戶安全
# Title: CUBE App安全嗎？你們的安全宣告為何？
# Text Content: 本行非常重視客戶個人資訊的安全性，為讓您能夠更安心的使用本行所提供的各項服務，針對資料傳輸或儲存，建置適當的保護機制(包括但不限於加密技術、使用者辨識系統及存取控制機制等)，以避免傳輸時被第三人截取得知。本行致力提供安全資訊環境及便捷服務，為您的資料做完善安全把關。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 如何買賣外幣？
# Text Content: 在進入外幣帳戶，點擊 “外幣買賣”
# 選擇 “交易幣別”
#  點擊幣別會出現下拉選單讓您選擇可買賣幣別
#  確認換匯資訊
# 確認交易成功，回外幣總覽
# --------------------------------------------------
# Categories: 信用卡消費明細與繳款
# Title: 我如何看每張信用卡 (包含正附卡) 的消費明細紀錄？
# Text Content: 在帳單明細頁，點擊帳單金額旁的 “>”
# 進入信用卡明細頁，左右滑動可切換不同信用卡」
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 數位外幣的功能服務時間？
# Text Content: 您可在CUBE App上買賣外幣、查詢匯率、並不定期享有外幣優惠活動。數位外幣的服務日同銀行外幣交易日。
# --------------------------------------------------
# Categories: 信用卡消費明細與繳款
# Title: 我可以在哪裡看到歷史帳單明細？
# Text Content: 在帳單明細頁，點擊帳單金額旁的 “>”
# 進入信用卡明細頁，右上角可點擊 "歷史帳單"
# --------------------------------------------------
# Categories: 信用卡消費明細與繳款
# Title: 為什麼「即時消費記錄」交易金額跟我實際刷卡金額不一樣?
# Text Content: 這裡顯示刷卡當下授權金額，如有國外刷卡或是飯店預授權等交易，可能會有不一致的情形，實際金額請以實際帳單明細為主。
# --------------------------------------------------
# Categories: 信用卡消費明細與繳款
# Title: 為什麼交易已經取消了，但「即時消費記錄」仍有顯示?
# Text Content: 此處顯示的是刷卡授權成功的紀錄，若後續有取消、退款，不會同步更新。只要商家後續完成刷退手續，此筆交易您就不需付款，建議您保留退刷簽單，並以實際帳單明細為主。
# --------------------------------------------------
# Categories: 信用卡消費明細與繳款
# Title: 我可以在CUBE App上用他行帳戶繳納國泰世華信用卡費嗎？
# Text Content: 可以，您可於繳卡費時選擇輸入同戶名之他行帳戶進行繳費，但需負擔新臺幣10元手續費用。
# --------------------------------------------------
# Categories: 信用卡消費明細與繳款
# Title: 我可以在CUBE App上顯示超商繳費的條碼嗎？
# Text Content: 可以，您可於信用卡帳單查詢時，選擇「超商繳款」功能，並將畫面顯示之條碼提供超商店員掃描繳款。
# 選擇 超商繳款
# 顯示條碼提供超商店員掃描繳款
# 註：「超商繳款」服務目前僅限全家便利商店、萊爾富便利商店適用，7-11繳款請至ibon操作列印繳款單方可繳納。
# --------------------------------------------------
# Categories: 信用卡消費明細與繳款
# Title: 信用卡繳費方式有哪些？
# Text Content: 1) 您可以設定自動扣繳流程圖
# 在帳單明細頁，點擊“完整資訊”進入信用卡頁
# 進入信用卡頁，點擊“自動扣繳設定”
#  點擊 ”立即申請
#  設定自動扣繳帳號與扣繳比例
#  設定新台幣自動扣繳成功 (設定將隔一工作日生效)
# 您可由原路口進入，變更自動扣繳設定
# 點選 “變更自動扣款”，即可調整設定
# 2) 您可以使用帳戶轉帳繳款流程圖
#  在帳單明細頁，點擊“帳戶繳款”
# 選擇繳款金額
#  確認繳款金額與帳戶無誤，點擊下一步
#  完成繳費，可設定“記住我的繳費帳號”與“通知”
# 3) 您可至便利超商使用條碼繳費 (大於 2 萬元帳單無法使用超商繳款)
# 在帳單明細頁，點擊“條碼繳款”
# 選擇繳費超商或是切換至 QR Code 繳費 (ATM)
# (大於 2 萬元帳單無法使用超商繳款)
# --------------------------------------------------
# Categories: 卡片安全與點數折抵
# Title: 什麼是信用卡安全鎖?
# Text Content: 信用卡安全鎖
# 信用卡安全鎖可以幫助您鎖定卡片。卡片鎖定後，將無法進行刷卡交易 (含行動支付)、預借現金、信用卡代繳費用。但已分期款、年費、離線交易 (例如: 機上消費、部分飯店 / 旅行社預刷卡等) 則不受限制仍可交易。
# 啟用卡片安全鎖將無法參與部分信用卡回饋活動。
# 鎖定效期為 30 天，期滿將自動解鎖 ; 若您想進行誇卡交易可隨時進行異動。若卡片遺失，請聯絡客服進行掛失、補發。
# 當您完成卡片鎖定，本行會寄通知信至您留存於本行的電子信箱。
# 首頁點擊進入信用卡完整資訊
# 在頁面最下方點擊卡片，進入 “我的信用卡”
#  在“卡片安全鎖”旁點擊“我要鎖卡”
#  卡片鎖定按鈕向右滑，即可開啟卡片安全鎖
#  若需解鎖，卡片鎖定按鈕再次向右滑，可解鎖
# --------------------------------------------------
# Categories: 卡片安全與點數折抵
# Title: 小樹點(信用卡)點數折抵消費 - 消費折抵申請有期限限制嗎?
# Text Content: 可折抵之消費僅限當月結帳日前可申請，若過了當月結帳日，則無法申請；但當月若有新增刷卡交易，可以在下個月結帳日前申請。
# --------------------------------------------------
# Categories: 卡片安全與點數折抵
# Title: 小樹點(信用卡)點數折抵消費 - 最高折抵點數是怎麼計算的?
# Text Content: 每10點折抵NT$10消費，折抵時須以10點為單位折抵，若持卡人點數足夠時可以折到消費金額的30%，若點數不足時系統將會自動換算可以折抵的上限。
# --------------------------------------------------
# Categories: 卡片安全與點數折抵
# Title: 小樹點(信用卡)點數折抵消費 - 什麼時候折抵金才會入帳呢?
# Text Content: 消費的商店請款後，隔日即會進行設定比對，若比對成功即會匯入到信用卡帳上，即可在CUBE App的未出帳看到折抵的負向金額。
# --------------------------------------------------
# Categories: 卡片安全與點數折抵
# Title: 小樹點(信用卡)點數折抵消費 - 什麼情況下會申請不成功?
# Text Content: 退貨或是商店沒有請款，原交易有部分退款造成金額比對不到，都會申請不成功，且將於30天後自動取消折抵申請(稅款交易為61天)，並歸還已扣除之點數。
# --------------------------------------------------
# Categories: 投資
# Title: 投資前需要完成什麼？
# Text Content: 您必須完成「信託契約簽署」與「投資屬性分析」後才可申購基金，如您尚未完成此兩項資格申請，請依照投資頁面的引導您完成上述兩項資格申請。
# 點擊“立即簽署"，進入信託契約簽署流程
# 閱讀相關說明書
#  進行手機認證
#  恭喜您完成線上信託契約簽署
# --------------------------------------------------
# Categories: 投資
# Title: 如何完成信託契約簽署？
# Text Content: 請留意，您須完成 「信託契約簽署」與「投資屬性分析」後才可申購基金。
# 點擊 “立即簽署”，進入信託契約簽署流程
# 閱讀相關說明書
#  進行手機認證
#  恭喜您完成線上信託契約簽署
# --------------------------------------------------
# Categories: 投資
# Title: 什麼是投資屬性分析 (KYC)？
# Text Content: 市場變化快速，依主管機關規定必須定期更新投資屬性分析，協助您更瞭解對風險的承受度及偏好，以提供適合的投資商品。請留意，您須完成 「信託契約簽署」與「投資屬性分析」後才可申購基金。
# 點擊 "完成投資屬性分析"
# 點擊“重新分析”
#  依照操作流程完成投資屬性分析，得到分析結果
# --------------------------------------------------
# Categories: 投資
# Title: 怎麼知道自己的 KYC 狀態？
# Text Content: 1) 若您尚未完成投資屬性分析，您可在投資首頁點擊 “完成投資屬性分析”
# 2) 若您已完成投資屬性分析，您可在投資首頁看到投資屬性的分析結果與效期。流程圖
# 點擊 “完成投資屬性分析”
# 投資屬性結果與效期
# --------------------------------------------------
# Categories: 投資
# Title: 國泰世華CUBE App 上有哪些基金操作功能？
# Text Content: 您可以在國泰世華CUBE App上進行基金申購、贖回、查看交易與漲跌資訊，透過【更多】選單，展開【基金】項目，即可選取其他基金相關功能，如【預約服務單】等。
# --------------------------------------------------
# Categories: 投資
# Title: 如何設定漲跌樣式？
# Text Content: 點擊 “更多” 後，選取 “設定”
# 選擇「顏色標示設定」
#  選擇臺灣樣式 (預設) 或國際樣式
# --------------------------------------------------
# Categories: 投資
# Title: 智能投資是什麼？
# Text Content: 國泰智能投資依照個人目標需求，透過大數據及世界級專家團隊建立專屬投資組合，並搭配24小時監控及再平衡機制，協助您的投資能持續朝目標邁進。
# ‌
# 相關交易與收費說明
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 人臉辨識在CUBE App上有哪些應用？
# Text Content: 非約定轉帳
# 啟用非約定轉帳
# 調整ATM提款限額
# 重設網銀密碼
# 集保App連結國泰世華銀行帳號
# 啟用手機無卡提款
# 申請數位外幣帳戶
# 申請大額換匯憑證
# 點我看更多介紹
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 使用人臉驗證轉帳有手機型號的限制嗎?
# Text Content: 不限機型與作業系統．只要手機有前置鏡頭可以拍攝，就可以使用CUBE App人臉驗證非約定轉帳服務。
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 我沒有註冊人臉辨識，可以在CUBE App上使用人臉驗證轉帳嗎?
# Text Content: 啟用人臉轉帳前，需要先在本行註冊人臉。若您尚未註冊人臉，也可直接透過CUBE  App註冊。
# 點我看教學
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 我該如何在CUBE  App上註冊人臉呢？
# Text Content: 點我看教學
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 我已經註冊人臉辨識了，該如何啟用人臉驗證轉帳呢?
# Text Content: 若您已透過其它通路註冊人臉辨識，可直接進入CUBE App啟用人臉驗證轉帳功能
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 我已經啟用人臉轉帳辨識驗證了，我要如何使用人臉轉帳呢？
# Text Content: 登入CUBE App，點選右下角【更多】
# 點選【交易設定】>【交易驗證方式】
#   啟用人臉辨識驗證
# 啟用成功
# 點我看教學
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 在國外也可以使用人臉驗證來轉帳嗎？
# Text Content: 可以喔！若您已在CUBE  App上啟用人臉辨識驗證方式，不論在國內或國外都可以直接使用人臉轉帳喔。
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 我的人臉辨識狀態已鎖定時，還可以繼續使用人臉驗證服務嗎?
# Text Content: 若人臉辨識狀態為鎖定時，無法使用人臉驗證相關功能。您可以透過視訊服務或分行臨櫃解鎖後，就可以繼續使用此服務。
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 沒有交易認證碼可以申請人臉驗證作為轉帳驗證方式嗎？
# Text Content: 可以喔！只要完成人臉註冊且開啟非約定轉帳功能，就可以在CUBE App使用人臉做為轉帳驗證工具。
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 如何用人臉辨識開啟非約定轉帳服務？
# Text Content: 登入 CUBE App，點擊「臺幣總額」
# 點擊「管理」
# 點擊「啟用非約定轉帳 我要啟用」
# 點擊「人臉辨識驗證」
# 完成人臉辨識驗證
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 每個帳號都需要個別啟用非約定轉帳服務嗎？
# Text Content: 不用喔！一個登入ID只要啟用一次就適用於全部的帳號都可以做非約轉服務囉！
# 備註：啟用非約轉服務後，CUBE App需另外設定轉帳驗證方式，可使用交易認證碼或人臉辨識服務（操作路徑：CUBE App登入首頁>右下角「更多」>轉帳驗證方式設定>可同時開啟人臉辨識驗證及交易驗證碼）
# --------------------------------------------------
# Categories: 人臉辨識
# Title: 註冊人臉辨識需要具備哪些身分條件呢?
# Text Content: 只要是本國自然成年人且有本行存款帳戶，就可以註冊人臉辨識喔!
# 如您已申請註銷本行帳戶，則無法繼續使用人臉驗證，惟人臉驗證停用生效日將以本行系統作業時間為主。
# --------------------------------------------------
# Categories: 彈力貸
# Title: 什麼是彈力貸？
# Text Content: 屬於您的專屬額度，不綁約、隨借隨還，有動用的金額才會計算利息。而且，在貸款期限內，每月只需繳利息，本金隨時可還，還完額度立即回復。
# --------------------------------------------------
# Categories: 彈力貸
# Title: 彈力貸利息怎麼計算？
# Text Content: 動撥金額才計息。採用以日計息，不動用不計息，當天動用當天還款也不計算利息。
# --------------------------------------------------
# Categories: 彈力貸
# Title: 彈力貸期限為多久？
# Text Content: 一年，優質客戶到期自動續約，免收費。
# --------------------------------------------------
# Categories: 彈力貸
# Title: 如何得知我的彈力貸申請進度呢？
# Text Content: 完成送出申請資料後，本行會以簡訊通知您申請結果及進度。
# --------------------------------------------------
# Categories: 彈力貸
# Title: 彈力貸系統服務時間？
# Text Content: 申請：營業日 09:00AM ~ 10:00PM
# 動用/還本：營業日 09:00AM ~ 10:00PM
# --------------------------------------------------
# Categories: 彈力貸
# Title: 如何申請彈力貸？
# Text Content: 彈力貸本息攤與彈力貸月繳息採邀請制，利用手機下載 CUBE App，可直接查詢專屬方案，申請開通額度、動用及還本。
# --------------------------------------------------
# Categories: 繳費
# Title: CUBE App提供的繳費稅服務有哪些？
# Text Content: CUBE App提供您多元金融服務如下：
# 電信費：中華電信、遠傳電信。
# 水電費：台北市水費、台灣水費、台電電費。
# 繳稅：房屋稅、地價稅、牌照稅、各類所得稅。
# 信用卡：本人信用卡、他人信用卡。
# 停車費：台北市、新北市、 嘉義市、台南市、高雄市。
# 其他：國民年金、國壽保費…等。
# --------------------------------------------------
# Categories: 繳費
# Title: 透過CUBE App進行繳費繳稅，有金額上的限制嗎？
# Text Content: 利用CUBE App繳費快速又方便，額度限制請參考下表:
# 項目
# 轉帳繳費
# 信用卡繳費
#  信用卡費
# 繳本人信用卡費: 無上限
# 繳他人信用卡費: 每日不得超過新臺幣十萬元，每月累計不得超過新臺幣二十萬元。
#  NA
# 電費
# 台水費
# 北市水費
# 電信費
#  每日不得超過新臺幣十萬元，每月累計不得超過新臺幣二十萬元。
#  無上限
# 各式稅單
#  每筆稅額超過二百萬元者，不適用此項功能。
#  NA
#  停車費
#  每日不得超過新臺幣十萬元，每月累計不得超過新臺幣二十萬元。
#  NA
# --------------------------------------------------
# Categories: 繳費
# Title: 我如何設定帳單自動通知服務？
# Text Content: 一、您可於單次繳納費用成功後，於結果頁選擇「下次需繳費時通知我」，CUBE App即可每月定期幫您詢問相關機關帳單訊息，並發送推播提醒通知給您。
# 二、CUBE App可提供之繳費通知服務項目如下: 電信費(中華電信、遠傳電信)、國泰世華信用卡帳單
# --------------------------------------------------
# Categories: 推播
# Title: CUBE App提供的推播通知服務有哪些？
# Text Content: CUBE App推播通知服務提供如下：
# 帳戶金額異動通知：帳戶出/入帳通知、外幣帳戶出/入帳通知、台幣定存到期通知。
# 信用卡/i刷金融卡通知：信用卡/i刷金融卡消費通知、信用卡繳費提醒通知、信用卡繳費入帳通知。
# 投資提醒通知：基金停利停損通知、匯率到價通知。
# 貸款通知：小額信貸繳息事前通知、放款撥貸通知。
# 官方通知：個人化優惠訊息。
# --------------------------------------------------
# Categories: 推播
# Title: 推播通知訊息可以保存多久？我能自行刪除嗎？
# Text Content: 目前推播通知訊息預設保存30天，30天後系統將自動刪除，您亦可於推播通知訊息首頁點擊右上「刪除」，自行選擇欲刪除項目。
# --------------------------------------------------
# Categories: 推播
# Title: 除了推播通知服務，CUBE App還提供那些通知服務？
# Text Content: 除了推播通知服務外，您登入CUBE App時，系統將寄送登入通知E-mail於您留存於本行之E-mail信箱。
# --------------------------------------------------
# Categories: 推播
# Title: 我如何於CUBE App設定與取消推播通知？
# Text Content: 您可以於登入後點擊開啟右下方之功能選單，選擇「設定 > 推播通知設定」進行設定。
# --------------------------------------------------
# Categories: 推播
# Title: 我如何於CUBE App設定與取消E-mail通知？
# Text Content: 因登入通知為讓您掌握CUBE App安全控管之重要訊息，目前並不提供取消服務，敬請見諒。
# --------------------------------------------------
# Categories: 推播
# Title: 我的手機裝置為何會重複收到推播通知訊息？
# Text Content: 如您擁有本行「國泰優惠」、「KOKO」等，並分別於應用程式設定推播通知訊息，則可能會重複收到由不同應用程式發出之推播通知訊息。
# --------------------------------------------------
# Categories: 推播
# Title: 我可以設定多台行動裝置接收推播通知訊息嗎？
# Text Content: 不行，推播通知僅可於單一身分證字號於單一裝置設定使用，於其他裝置用相同身分證字號設定，原裝置申請之推播通知服務將自動失效，並於新設定之裝置接收推播通知訊息。
# --------------------------------------------------
# Categories: 分行取號
# Title: 我該如何查詢服務據點(分行/ATM)？
# Text Content: 您可以點擊開啟右下方之「更多」，選擇「服務據點/取號」查詢分行/ATM相關資訊。
# --------------------------------------------------
# Categories: 分行取號
# Title: 我該如何使用「分行取號」服務？可預約取號服務有哪些？
# Text Content: 當您於服務據點查詢到想前往分行，點擊該分行即可出現分行訊息，您可點擊分行訊息右下方「取號」進行預約。
# CUBE App之分行取號服務提供如下：台幣收付、外幣業務、服務台、開戶諮詢...等其他服務。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶的功能有哪些？
# Text Content: 子帳戶功能說明：
# 可約定代扣繳 （信用卡款自動扣繳、公共事業代扣繳）。
# 可作為網路基金下單及網路銀行外匯服務扣款帳戶。
# 可作為證券交割帳戶（含複委託）。
# 可作為貸款撥款帳戶（母帳戶為3-1類數存者除外）。
# 母帳戶和子帳戶於網路銀行可直接相互轉帳，不需逐一約定（子帳號對子帳號也可直接相互轉帳），惟母帳戶需先開啟轉出功能。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 如何申請「用戶代號」及「網銀密碼」？
# Text Content: 本行成年存戶請用以下方法申請：
# 分行申請：持身分證正本與帳戶原留印鑑，親洽任一分行即可申請。
# ATM申請：持國泰世華銀行所發行之晶片金融卡，透過國泰世華銀行ATM申請。
# CUBE App申請_視訊客服：透過國泰世華CUBE  App，在登入頁面選擇【忘記代號/密碼】→ 選擇【視訊客服】進行簡訊OTP驗證及身分證資料驗證，即可進入視訊服務申請。
# 本行未成年存戶請偕同法定代理人雙方/監護人於營業時間親洽任一分行申請，並攜帶下列正本資料：
# 未成年人-【戶口名簿/戶籍謄本/身分證正本】+【第二身分證件】+【原留印鑑】 。
# 法定代理人雙方-【身分證正本】+【第二身分證件】。
# 單親法定代理人/監護人-【身分證正本】+【第二身分證件】+ 提供載明監護權歸屬的文件，如：戶口名簿或戶籍謄本或法院判決書/裁定書等文件正本。
# 如法定代理人一方不克前來，需另徵提【委託人身分證正本】+【第二身分證件】+【辦理存款業務同意書】 。
# 一旦申請或重設，須於指定時效內進行設定，始完成啟用流程，效期說明：密碼單為15日(須以密碼單內之指定用戶代號及網銀密碼登入CUBE網銀或CUBE App變更啟用)；簡訊連結為簡訊發送後72小時內(設定後始生效力)。
# 本行正卡卡友（不含商務卡）請用以下方法申請：
# CUBE  App、CUBE 網路銀行申請：於簡訊OTP驗證後自行設定用戶代號及網銀密碼。
# 本行智能客服：進入智能客服對話並選擇【信用卡戶】，輸入身分證字號並完成簡訊OTP驗證後，即可設定用戶代號及網銀密碼。
# 備註：信用卡理網銀碼服務範圍僅限信用卡相關查詢功能，若您同時為本行存款戶，欲使用帳務功能，請參閱存戶申請網銀密碼方式，體驗完整的數位理財服務。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 用戶代號或網銀密碼輸入錯誤致失效或忘記無法登入網路銀行怎麼辦？
# Text Content: 本行成年存戶請用以下方法申請重設：
# 分行申請：持身分證正本與帳戶原留印鑑，親洽任一分行即可申請。
# ATM申請：持國泰世華銀行所發行之晶片金融卡，透過國泰世華銀行ATM申請。
# CUBE  App申請_視訊客服：透過國泰世華CUBE  App，在登入頁面選擇【忘記代號/密碼】→ 選擇【視訊客服】進行簡訊OTP驗證及身分證資料驗證，即可進入視訊服務申請重設。
# CUBE  App申請_人臉辨識服務：如已註冊過人臉辨識，透過國泰世華CUBE  App，在登入頁面選擇【忘記代號/密碼】→ 選擇【人臉辨識】進行簡訊OTP驗證及人臉驗證，即可申請重設。
# 本行未成年存戶請偕同法定代理人雙方/監護人於營業時間親洽任一分行申請，並攜帶下列正本資料：
# 未成年人-【戶口名簿/戶籍謄本/身分證正本】+【第二身分證件】+【原留印鑑】 。
# 法定代理人雙方-【身分證正本】+【第二身分證件】。
# 單親法定代理人/監護人-【身分證正本】+【第二身分證件】+ 提供載明監護權歸屬的文件，如：戶口名簿或戶籍謄本或法院判決書/裁定書等文件正本。
# 如法定代理人一方不克前來，需另徵提【委託人身分證正本】+【第二身分證件】+【辦理存款業務同意書】 。
# 一旦申請或重設，須於指定時效內進行設定，始完成啟用流程，效期說明：密碼單為15日(須以密碼單內之指定用戶代號及網銀密碼登入CUBE網銀或CUBE App變更啟用)；簡訊連結為簡訊發送後72小時內(設定後始生效力)。
# 本行正卡卡友（不含商務卡）請用以下方法申請：
# CUBE  App、CUBE 網路銀行申請：於簡訊OTP驗證後自行設定用戶代號及網銀密碼。
# 本行智能客服：進入智能客服對話並選擇【信用卡戶】，輸入身分證字號並完成簡訊OTP驗證後，即可設定用戶代號及網銀密碼。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 什麼是登入兩步驟驗證？
# Text Content: 類似google、Facebook、IG的雙重驗證功能，有陌生裝置登入時需要進行第二道驗證(OTP/推播)來加強身分確認，保障帳戶安全性。
# 建議您可登入CUBE App/網銀啟用登入兩步驟驗證，未來陌生裝置登入時，除原先登入的帳號密碼/快速登入驗證方式外，需再進行OTP驗證後才能登入完成，多一重登入保護力喔。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳, 帳務性問題
# Title: 如何使用CUBE App/網銀轉帳到其他帳戶？
# Text Content: 約定帳戶轉帳：若要設定約定轉帳帳號，請您攜帶身分證正本及原留印鑑親至任一分行設定，或透過CUBE  APP視訊約定服務設定。
# 非約定帳戶轉帳：若您已開啟非約定轉帳功能，並申請「人臉辨識」或「交易認證碼」，則可進行非約定帳戶轉帳。
# 本人本行帳戶轉帳：請您至CUBE 網銀「轉帳帳號設定」功能，選擇「本人國泰世華帳戶轉帳」，並透過簡訊OTP驗證完成設定，即可進行本人本行帳戶轉帳服務。
# --------------------------------------------------
# Categories: 帳務性問題, 臺外幣帳務與轉帳
# Title: 在CUBE網路銀行/App上，如何只做查詢，並停止轉帳功能？如果要恢復轉帳如何辦理 ?
# Text Content: 若只需使用查詢功能，登入CUBE網路銀行後，至「申請設定」執行「轉帳停用」功能，可分別停用「約定戶轉帳」或「非約定戶轉帳」。
# 若需恢復「約定戶轉帳」，請攜帶身分證及原留印鑑至任一分行辦理，無法直接由網路申請以保障客戶帳戶安全。若需恢復「非約定戶轉帳」，可至
# 本行ATM開啟
# 在CUBE  App經人臉辨識驗證後開啟(點擊臺幣總額>右上帳戶資訊>臺幣帳戶資訊>啟用非約定轉帳>人臉辨識驗證成功>非約定轉帳啟用成功)
# 攜帶身分證及原留印鑑至任一分行申請
# --------------------------------------------------
# Categories: 手機/Email共用, 手機/Email共用
# Title: 若有特定共用需求，我能與幾個特定關係對象共用手機門號/電子郵件？
# Text Content: 共用對象若符合特定關係：血親三等親內、姻親二等親內、法定代理人或監護人之關係，皆可備妥關係文件後於分行臨櫃進行申請，若共用人數≤ 5人，亦可於CUBE網銀線上辦理。*CUBE網銀申請路徑：[申請設定]→[資料異動]→[修改個人資料]→共用註記申請/進度查詢
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 我可以有哪些非約定轉帳的驗證方式？
# Text Content: 1.  啟用人臉辨識
# 點擊"更多"後，選取"設定">"交易設定">"人臉辨識註冊"
# 點擊"馬上開始"
#  同意人臉服務條款
#  簡訊OTP驗證
#  拍照前之注意事項
#  拍攝人臉註冊照
#  註冊完成，點擊立即啟用
#  開啟人臉辨識驗證
# 2. 啟用交易認證碼
# 請先下載且登入本行CUBE  App，從「更多」-「交易設定」-「交易驗證方式」中，選擇「啟用交易認證碼」，透過SIM驗證與簡訊OTP進行驗證後，自行設定一組6位數的密碼。
# *SIM驗證透過臺灣網路認證股份有限公司(TWID身分識別中心)所提供的行動電話身分驗證服務，向五大電信業者(中華電信、台灣大哥大、遠傳、台灣之星、亞太)或ibon mobile統一超商電信比對您的手機門號與本行留存的手機是否一致，提供您更安全與便利的線上服務。開始進行SIM驗證前，請關閉WiFi，並確認您的手機電信商為五大電信或ibon電信，使用之SIM卡與留存於本行手機號碼一致。
# 點擊"更多"後，選取"設定">"交易設定">"交易驗證方式"
# 點擊"啟用交易認證碼"
#  關閉WIFI，確認申請限制
#  執行SIM驗證
#  簡訊OTP驗證
#  設定交易認證碼
#  交易認證碼設定成功
# --------------------------------------------------
# Categories: 帳戶安全
# Title: CUBE App會取用我行動裝置那些授權項目？
# Text Content: 為了提供您更好、更方便的行動金融服務，CUBE App將下取用您行動裝置的特定功能，如下:
# 存取權限
# 用途
# 推播
# 提供推播通知服務、交易認證推播
# 位置
# 提供附近分行及ATM服務據點
# 相片/多媒體/檔案
# 線上申辦業務文件上傳、截取交易結果畫面供客戶留存。
# 相機
# 掃描信用卡進行圖形辨識，將卡號自動帶入欄位中
# 裝置ID
# 提供裝置綁定
# 寫入設定
# 顯示繳費條碼時，調整亮度
# 網路狀態
# 判斷離線模式
# APPle Wallet
# 增加本行信用卡至APPle Wallet
# 裝置狀態
# 交易密碼需使用裝置識別碼(IMEI)
# 震動
# 推播通知、條碼掃描
# 開機就執行
# 交易密碼設定
# 清除暫存
# 清除App執行時不使用或過期的暫存
# 閃光燈
# 圖形辨識掃描信用卡或掃描條碼
# 螢幕喚醒
# 交易密碼
# 取得GCM訊息
# 交易密碼取得GCM(Google Cloud message)
# Wi-Fi 狀態
# SIM驗證時須檢測Wi-Fi連線是否開啟，開啟不可使用該服務
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶有什麼使用限制？
# Text Content: 子帳戶使用限制如下：
# 子帳戶無法申請金融卡。
# 子帳戶未提供存摺，但能透過網路銀行或綜合對帳單查詢交易明細。
# 子帳戶無法立印鑑卡，若需臨櫃交易則以該母帳戶原留印鑑核印。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 我一定要啟用登入兩步驟驗證嗎？
# Text Content: 為提升登入帳戶安全，建議您啟用此服務，可登入CUBE App/網銀後至設定頁操作開關(可參考下方路徑)。
# 若您有使用多裝置登入的習慣或與家人帳號都於同一裝置登入操作，為了確保您在使用本行CUBE App/網銀之安全性，會請您必須啟用此服務。
# 啟用登入兩步驟路徑：
# CUBE App>更多>一般設定>登入兩步驟驗證
# CUBE 網銀>申請設定>登入兩步驟驗證
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 我可以在常使用的登入裝置上略過登入第二步OTP驗證嗎？
# Text Content: 如果不想每次在電腦或手機上登入CUBE App/網銀帳戶時都要進行OTP驗證步驟，請將裝置加入信任清單，下次登入時就免第二步OTP驗證囉。
# 提醒：
# ※ 為確保安全性，建議不要將公用電腦、暫時性裝置、無痕瀏覽器加入信任裝置清單
# ※ 透過無痕模式、私密瀏覽方式開啟瀏覽器會視為陌生裝置而需進行OTP驗證。
# 設定登入信任裝置路徑：
# CUBE App>更多>一般設定>登入兩步驟驗證
# CUBE 網銀>申請設定>登入兩步驟驗證
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 以陌生裝置登入時無法完成OTP驗證，有其他的驗證方式嗎？
# Text Content: OTP預設以簡訊方式發送至您留存於本行的手機號碼，您也可改選以Email方式收OTP進行驗證。
# 提醒您手機號碼跟Email基本資料要留存最新資訊，確保OTP都可以收到。
# 查詢/變更手機號碼與Email路徑：
# 登入CUBE App>更多>查看個人資料>編輯個人資料
# 變更手機號碼：請完成手機OTP驗證與身分證件照上傳，即可透過視訊客服變更手機號碼。
# 變更Email：請輸入新Email OTP，接著完成手機OTP驗證，即可變更Email。
# 登入CUBE 網銀>申請設定>修改基本資料
# 變更手機號碼：請備妥讀卡機及晶片金融卡，即可在CUBE網銀變更手機號碼。
# 變更Email：請輸入新Email OTP，接著完成手機OTP驗證，即可變更Email。
# 本行存戶可至國泰世華任一台ATM進行手機門號（不包含未成年）。
# 本行存戶攜帶證件到國泰世華任一間分行修改基本資料，卡友可致電客服進行修改。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 登入兩步驟服務的OTP次數規則？
# Text Content: 當您以陌生裝置登入時需先驗證OTP，OTP的錯誤次數上限為當天連續錯誤達5次時(簡訊+Email合計)，即無法繼續驗證，需請您等到隔日才能操作。
# 若您不慎錯誤次數達上限並有急需查詢帳戶/交易時，請與客服聯繫以協助排除問題。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 我在同一台手機重新安裝CUBE App或是使用同一台裝置登入CUBE 網銀，且裝置都有加入信任裝置，為何還登入需要OTP驗證？
# Text Content: CUBE App：若裝置重置、卸載CUBE App後重新安裝的情形，登入時會視為陌生裝置而需要進行OTP驗證，驗證完成後可再重新設定為信任裝置。
# CUBE 網銀：若您習慣使用無痕模式、私密瀏覽方式開啟瀏覽器或有清除瀏覽器歷史紀錄的情形，將影響裝置的識別，被視為陌生裝置而需進行OTP驗證。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 加入信任裝置有上限嗎？
# Text Content: 一個人在CUBE App可設定3台裝置； CUBE 網銀可設定10台裝置，如果達到設定上限，建議您檢視信任清單，刪除不常用的裝置後，再將常用的登入裝置加入至信任清單。為確保安全性，建議不要將公用電腦、暫時性裝置、無痕瀏覽器加入信任裝置清單。
# 管理信任裝置清單路徑：
# CUBE App>更多>一般設定>登入兩步驟驗證
# CUBE 網銀>申請設定>登入兩步驟驗證
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 我的信任裝置清單內，為何有多筆相同的裝置資訊？
# Text Content: CUBE App：若裝置重置、卸載CUBE App後重新安裝的情形，登入時會視為陌生裝置而需要進行OTP驗證，驗證完成後可再重新設定為信任裝置，信任裝置清單內就會有重複的裝置資訊。
# CUBE 網銀：若您習慣使用無痕模式、私密瀏覽方式開啟瀏覽器或有清除瀏覽器歷史紀錄的情形，將影響裝置的識別，被視為陌生裝置而需進行OTP驗證，驗證完成後可再重新設定為信任裝置，信任裝置清單內就會有重複的裝置資訊
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 加入過的信任裝置超過一年未登入，為什麼會被自動刪除？
# Text Content: 曾經加入過的信任裝置超過一年未登入，為確保您的登入安全性將自動移除。若有使用上的需求，請重新OTP驗證後再次設定為信任裝置。
# --------------------------------------------------
# Categories: 手機/Email共用, 手機/Email共用
# Title: 如何修改留存於銀行或信用卡的手機門號/電子郵件？
# Text Content: 欲修改您留存於本行的手機門號/電子郵件，請參考以下方式辦理 :
# CUBE App>更多>查看個人資料>編輯個人資料進行查詢/變更
# - 變更手機號碼：請完成手機OTP驗證與身分證件照上傳，即可透過視訊客服變更手機號碼。
# - 變更Email：請輸入新Email OTP，接著完成手機OTP驗證，即可變更Email。
# CUBE 網銀>申請設定>修改基本資料進行查詢/變更
# - 變更手機號碼：請備妥讀卡機及晶片金融卡，即可在CUBE網銀變更手機號碼。
# - 變更Email：請輸入新Email OTP，接著完成手機OTP驗證，即可變更Email。
# 可至國泰世華任一台ATM進行手機門號變更。
# 本行存戶請到國泰世華任一間分行修改基本資料，卡友可致電客服修改基本資料
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 什麼是太好轉服務？有手續費嗎？有什麼交易限制嗎？收款方多久內要完成取款？交易設定完成後，可以在哪邊查詢？
# Text Content: 客戶可設定取款金額、轉出帳號與一組6位數取款密碼，並藉由簡訊或社群軟體通知收款人至本行指定網址取款，收款人必須輸入收款帳號與轉出方設定的取款密碼方可完成取款；收款方完成取款當下系統將由轉出帳號扣款並轉至收款方指定帳戶。
# 取款人所輸入的帳戶若非國泰世華銀行帳戶，轉出方將支付15元跨行轉帳手續費。
# 客戶必須先臨櫃開通『非約定轉帳』功能；太好轉服務交易限額比照非約定轉帳(每筆新臺幣5萬元、每日新臺幣10萬元、每月新臺幣20萬元)，「非約定帳戶轉帳」限額計入網路銀行、CUBE App合併計算；網路銀行及CUBE App之繳費、繳稅交易金額不計入此非約轉額度。
# 收款方需於24小時內完成取款，超過取款時間交易將自動取消。
# 客戶太好轉服務設定完成後，可於登入後點擊開啟左上方之功能選單，選擇「帳戶 > 台幣轉帳」功能頁面下方「App轉帳紀錄」中查詢交易資料。
# --------------------------------------------------
# Categories: 帳戶安全
# Title: CUBE App的服務條款為何？
# Text Content: 我們的服務條款請參照以下連結：
# 若您使用的是Android: ‌  使用者隱私條款
# 若您使用的是iOS:‌  使用者隱私條款
# --------------------------------------------------
# Categories: 子帳戶
# Title: 母子帳戶要如何銷戶？
# Text Content: 子帳戶銷戶方式如下：
# 登入個人CUBE App，點選【臺幣總額】 > 選擇欲銷子帳戶右方更多功能 >【刪除子帳戶】
# 申請銷戶時，該子帳戶內餘額不得超過新臺幣伍萬元，完成子帳戶銷戶後，該子帳戶之存款餘額及結算之利息將自動轉入母帳戶，且該子帳戶所辦理之各項委託代扣繳、扣款等，將於子帳戶銷戶同時自動終止，如仍有委託代扣繳、扣款之需求，應另辦理授權自動扣款。
# ※母帳戶如欲銷戶前，應將母帳戶下所有子帳戶辦理銷戶後，始得將母帳戶銷戶。
# --------------------------------------------------
# Categories: 手機/Email共用, 手機/Email共用
# Title: 如果陌生人使用了我的手機門號該怎麼辦？
# Text Content: 請您依照流程指引完成 Mobile ID行動身分識別服務，驗證為本人門號後，即可繼續本行的相關服務申請。Mobile ID行動身分識別前，請確定您的手機門號為本國自然人申請之五大電信月租型門號，若您非本國自然人身分或手機門號非五大電信月租型，您可攜帶近三個月內的電信帳單等門號證明文件至CUBE網銀或分行臨櫃辦理，若您使用公司配發門號，除近三個月的電信帳單外，需額外備妥在職證明文件。
# *CUBE網銀申請路徑：[申請設定]→[資料異動]→[修改個人資料]→共用註記申請/進度查詢
# *五大電信商：中華電信、台灣大哥大、台灣之星、亞太電信、遠傳電信(含ibon mobile)
# --------------------------------------------------
# Categories: 手機/Email共用, 手機/Email共用
# Title: 如果陌生人使用了我的手機門號，我的交易認證碼該如何申請？
# Text Content: 請您至 CUBE App側選單中的更多>交易設定>交易驗證方式，選擇「啟用交易認證碼」，依照流程指引完成 Mobile ID行動身分識別服務，驗證為本人門號後，可以繼續交易認證碼的申請。Mobile ID行動身分識別前，請確定您的手機門號為本國自然人申請之五大電信月租型門號，若您非本國自然人身分或手機門號非五大電信月租型，您可攜帶近三個月內的電信帳單等門號證明文件至CUBE網銀或分行臨櫃辦理，若您使用公司配發門號，除近三個月的電信帳單外，需額外備妥在職證明文件。
# *CUBE網銀申請路徑：[申請設定]→[資料異動]→[修改個人資料]→共用註記申請/進度查詢
# *五大電信商：中華電信、台灣大哥大、台灣之星、亞太電信、遠傳電信(含ibon mobile)
# --------------------------------------------------
# Categories: 手機/Email共用, 手機/Email共用
# Title: 我已經申請與家人共用了，為何我的家人仍無法使用？
# Text Content: 手機/Email共用需由每位「非門號持有人」本人自行申辦。
# 「非門號持有人」需備妥您與手機門號共用者的關係證明文件正本(身分證、居留證、戶口名簿/戶籍謄本、法律判決書)，至CUBE網銀或分行臨櫃申辦手機/Email共用註記。目前僅開放申請特定關係對象共用手機門號/電子郵件，包含血親三等親內、姻親二等親內、法定代理人、或監護人之關係。一般客戶共用申請成功後，共用效期為期三年、未成年則至成年。
# 「門號持有人」則可透過 Mobile ID行動身分識別服務，驗證為本人門號後，繼續本行的相關服務申請。
# 舉例說明:
# 若您與媽媽、爸爸共用手機門號，您是「門號持有人」，您的媽媽、爸爸是「非門號持有人」，您可透過 Mobile ID行動身分識別服務，驗證為本人門號後，繼續本行的相關服務申請。您的媽媽、爸爸需各自備妥與您的關係證明文件後，至CUBE網銀或分行臨櫃申辦手機/Email共用註記。
# *CUBE網銀申請路徑：[申請設定]→[資料異動]→[修改個人資料]→共用註記申請/進度查詢
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 「交易認證碼」是什麼？可使用在那些平台與交易上？
# Text Content: 您只要是本行的存戶並開啟CUBE 網銀非約轉功能，皆能透過CUBE  App申請啟用交易認證碼，日後以下平台與交易即可輸入此組自設密碼進行交易認證。
# CUBE 網銀：非約定轉帳、台幣匯出匯款(需臨櫃申請註記)。
# CUBE  App：非約定轉帳。
# 啟用交易認證碼：請先下載且登入本行CUBE  App，從側選單中「更多」-「交易設定」-「交易驗證方式」中，選擇「啟用交易認證碼」，透過SIM驗證與簡訊OTP進行驗證後，自行設定一組6位數的密碼
# *SIM驗證透過臺灣網路認證股份有限公司(TWID身分識別中心)所提供的行動電話身分驗證服務，向五大電信業者(中華電信、台灣大哥大、遠傳、台灣之星、亞太)或ibon mobile統一超商電信比對您的手機門號與本行留存的手機是否一致，提供您更安全與便利的線上服務。開始進行SIM驗證前，請關閉WiFi，並確認您的手機電信商為五大電信或ibon mobile統一超商電信，使用之SIM卡與留存於本行手機號碼一致。
# 啟用交易認證碼教學
# --------------------------------------------------
# Categories: 帳戶安全
# Title: 我是舊CUBE App用戶，該如何升級為新版CUBE App？
# Text Content: 您可以依裝置的作業系統至
# ‌
#  Google Play商店
# 或
# ‌
# APP store
# 查詢「國泰世華CUBE網銀」，選擇「更新」，即可使用更好、更方便的新版CUBE App。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶銷戶失敗的原因有哪些？
# Text Content: 若子帳戶有下列入（扣）帳相關約定或事故，無法於線上銷戶：
# 存入該帳戶之今/次交票未入帳。
# 為基金下單扣款帳戶。
# 帳戶餘額為負數或超過5萬元。
# 為定存轉息帳號或零存整付扣款帳號。
# 為證券連結帳戶。
# 有法院扣押或其他狀況。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 交易認證碼的申請/啟用資格是什麼？
# Text Content: 您只要是本行的存戶，並開啟CUBE網銀非約轉功能，皆能透過CUBE  App申請啟用交易認證碼。 請先下載且登入本行CUBE  App，從側選單中「更多」-「交易設定」-「交易驗證方式」中，選擇「啟用交易認證碼」，透過SIM驗證與簡訊OTP進行驗證後，自行設定一組6位數的密碼，日後非約定轉帳交易即可輸入此組自設密碼進行交易認證。 開始申請交易認證碼前，請關閉WiFi，並確認您的手機電信商為五大電信(中華電信、台灣大哥大、遠傳、台灣之星、亞太)或ibon mobile統一超商電信，使用之SIM卡與留存於本行手機號碼一致。
# 啟用交易認證碼教學
# --------------------------------------------------
# Categories: 帳戶安全
# Title: 我升級為新版CUBE App後，一定要重新設定隨身密碼嗎？
# Text Content: 為了提供您更方便且安全的金融服務，升級後必須重新申辦交易認證碼(原隨身密碼)。舊隨身密碼會失效，無法成功轉帳，故您更新成新版CUBE App後，請從右下方之更多功能選單中「交易認證碼」啟用交易認證碼，才能進行非約定帳戶轉帳。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 一個人可以加開幾個子帳戶？
# Text Content: 每一母帳戶下僅能同時設定5個子帳戶、每人申請開立次數最多以15個為限，新增後刪除仍計入使用數量。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 我不想用交易認證碼了，如何停用?
# Text Content: 交易認證碼無使用時間的限制。若要取消啟用，您可將綁定交易認證碼的國泰世華CUBE  App移除後重新安裝；或本人持「身分證正本」及「帳戶原留印鑑」洽國泰世華任一分行申請停用。若更換手機裝置，原交易認證碼將於新手機裝置申請新密碼後失效。
# --------------------------------------------------
# Categories: 帳戶安全
# Title: 為何之前提供的服務在新版CUBE App找不到了？
# Text Content: 新版CUBE App設計以輕便好用的隨身金融為原則，經由使用者研究分析顯示多數使用者希望能擁有更簡單直覺的選單與操作，故本次改版以80/20法則，提取原CUBE App上80%的最常使用的功能進行流程優化與設計，希望提供給您更快速流暢的服務，未來我們也將聆聽您的需求，提供更多、更好、更方便的服務。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 不想收到安全守門通知可以關掉嗎？
# Text Content: 異常交易警示通知屬權益類通知，為保護您的交易安全，當本行偵測到疑似非本人登入的情境，將主動提醒您進行查證。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 我都在台灣登入CUBE  App/CUBE網銀，為何會收到新地區登入異常通知？
# Text Content: 若有使用VPN跨區域登入CUBE  App/網銀，將會收到登入警示通知。若無相關操作行為，請透過CUBE  App/ 網銀確認您的登入紀錄是否有異常，以保障帳戶安全。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶的利率及起息額？
# Text Content: 利率及起息額同活期儲蓄存款帳戶之規範，子帳戶無薪轉優惠利率，各母子帳戶獨立計息。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 申請交易認證碼交易認證時，為何會失敗？
# Text Content: CUBE App申請啟用交易認證須透過SIM驗證與簡訊OTP進行驗證後，自行設定一組6位數的密碼。開始申請交易認證碼前，請關閉WiFi，並確認您的手機電信商為五大電信或ibon電信，使用之SIM卡與留存於本行手機號碼一致，即可完成SIM驗證與交易認證碼申請。
# *SIM驗證透過臺灣網路認證股份有限公司(TWID身分識別中心)所提供的行動電話身分驗證服務，向五大電信業者(中華電信、台灣大哥大、遠傳、台灣之星、亞太)或ibon mobile統一超商電信比對您的手機門號與本行留存的手機是否一致，提供您更安全與便利的線上服務。開始進行SIM驗證前，請關閉WiFi，並確認您的手機電信商為五大電信或ibon電信，使用之SIM卡與留存於本行手機號碼一致。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶可以在哪交易？
# Text Content: 子帳戶能於個人網路銀行及網路銀行App交易，也能於本行ATM使用所連結之母帳戶金融卡提款（提款限額與母帳戶合併計算）。若需臨櫃交易則以該所屬母帳戶之原留印鑑核印。
# ※母帳戶若無留存印鑑，則請先申請留存印鑑。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 忘記交易認證碼怎麼辦？
# Text Content: 您可從側選單中「更多」-「交易設定」-「交易驗證方式」中，選擇「交易認證碼」啟用，透過SIM驗證與簡訊OTP進行驗證後，重新設定一組6位數的密碼。
# 啟用交易認證碼教學
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶可以申請證券授扣嗎？
# Text Content: 子帳戶可以申請證券授扣，若為國泰證券，可於網路銀行App申請授扣；若為其他券商請至分行臨櫃簽署委託書申請。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 更換或遺失手機時，應如何處理?
# Text Content: 更換手機時，只要於新手機重新安裝CUBE  App後，從「更多」-「交易設定」-「交易驗證方式」中，選擇「交易認證碼」啟用交易認證碼，即可註銷舊手機中的交易認證碼，並於新手機啟用。 若手機遺失欲停止時，除了可以重設新密碼且讓舊密碼失效外，也可以本人持「身分證正本」及「帳戶原留印鑑」洽國泰世華任一分行申請停用。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 如何查詢子帳戶的帳號？
# Text Content: 登入網銀App後點選臺幣總額，即可看見子帳號。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 交易認證碼連續錯誤怎麼辦？
# Text Content: 若交易時密碼輸錯達四次，交易認證碼將失效，必須重新啟用交易認證碼，才得以進行非約轉交易認證。從側選單中「更多」-「交易設定」-「交易驗證方式」中，選擇「啟用交易認證碼」，透過SIM驗證與簡訊OTP進行驗證後，重新設定一組6位數的密碼。
# 啟用交易認證碼教學
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶的轉帳限額？
# Text Content: 子帳戶線上交易限額如下：
# 網銀之約定轉帳限額母子帳戶共同累計。
# 母帳戶所約定的約定轉帳帳號同時適用於子帳戶，子帳戶不可單獨設定。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 若密碼輸入正確，但無法成功完成交易?
# Text Content: 請先確認轉入帳號是否正確? 若重試後仍有問題，也可試著重新啟用「交易認證碼」。
# 啟用交易認證碼教學
# --------------------------------------------------
# Categories: 子帳戶
# Title: 要如何辨別子帳戶的帳號？
# Text Content: 子帳戶的帳戶等級說明如下：
# 子帳戶帳號前3碼與母帳戶相同(表示開戶分行別相同)。
# 帳號4~5碼為「70」則為子帳戶。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 每個人可以申請幾個交易認證碼？
# Text Content: 每一身分ID只能綁定一台行動裝置使用交易認證碼。若您更換手機/裝置時，需於新手機/裝置重新下載本行CUBE App並登入，從「更多」-「交易設定」-「交易驗證方式」中，重新「啟用交易認證碼」，原綁定行動裝置之「交易認證碼」將立即失效。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶跟一般存款帳戶有什麼不同？
# Text Content: 子帳戶的帳戶等級說明如下：
# 子帳戶不可單獨存在，需依附於母帳戶下。
# 母子帳戶其一如依法遭假扣押、假處分、強制執行或其他法律處分時，其效力亦及於同組其他母子帳戶。
# 子帳戶不可作為開立數位存款帳戶時，供他行驗身之帳戶。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 申請交易認證碼需要費用嗎？
# Text Content: 不需費用。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 子帳戶提款服務介紹
# Text Content: 子帳戶不提供金融卡申請，但可使用母帳戶的提款卡至本行ATM提領現鈔。
# ※子帳戶提款限額與母帳戶併計。
# --------------------------------------------------
# Categories: 子帳戶
# Title: KOKO母子帳戶差異
# Text Content: 子帳戶為網銀App專屬服務，KOKO子帳戶將有以下限制：
# KOKO子帳戶資訊、交易明細僅提供於網銀App查詢，無法於KOKO App查詢。
# KOKO子帳戶的出入帳推播通知，僅於網銀App呈現，不會於KOKO App推播顯示。
# KOKO子帳戶不適用KOKO母帳戶所提供之跨轉跨提優惠。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 綜合活期儲蓄存款母子帳戶，開立定存差異
# Text Content: 綜活儲母子帳戶開立定存的種類不同：
# 綜活儲母帳戶：綜定存。
# 綜活儲子帳戶：因子帳戶為無摺產品，定存的形式為電子存單或實體存單。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 目標儲蓄的申請資格是什麼？
# Text Content: 設定目標儲蓄方式如下：
# 需先具備子帳戶，且單一子帳戶僅能對應一組目標儲蓄排程，設定方式說明：
# 登入網路銀行App，點選【臺幣總額】> 選擇子帳戶右方更多功能 >【新增目標儲蓄】> 即可依畫面步驟進行操作。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 目標儲蓄可透過什麼管道設定？
# Text Content: 設定目標儲蓄方式如下：
# 登入網路銀行App，點選【臺幣總額】> 選擇子帳戶右方更多功能 >【新增目標儲蓄】> 即可依畫面步驟進行操作。
# ※提醒您，設定通路僅限網路銀行App。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 目標儲蓄是什麼？
# Text Content: 目標儲蓄的介紹如下：
# 目標儲蓄為每月定期自您的母帳戶執行固定金額的轉帳交易，轉入關聯子帳戶，進行儲蓄。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 目標儲蓄的設定及功能有哪些？
# Text Content: 目標儲蓄設定說明：
# 目標儲蓄為每月自您的母帳戶執行固定金額的轉帳交易，轉入關聯子帳戶。
# 輸入期望存滿的金額以及期間後，將為您試算出平均每次扣款金額。
# 每次的儲蓄金額為：目標儲蓄總金額除以儲蓄期間，若無法除盡，則小數點第一位將無條件進位。
# 設定完成後，每月轉帳日前三個工作天將發送email通知信，提醒您請備妥預計儲蓄金額。
# ※儲蓄金額舉例：若目標儲蓄總金額輸入$100,000，儲蓄期間為12個月， $100,000/12=$8,333.33333…，則每月扣款金額將無條件進位為$8,334， 每月儲蓄$8,334存滿12個月後，目標儲蓄總金額將為$8,334*12=$100,008"
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 使用交易認證碼進行非約定帳戶轉帳之交易有金額限制嗎？
# Text Content: 預設限額：每筆新臺幣5萬、每日新臺幣10萬元、每月新臺幣20萬元。
# 自設限額：您可持身分證正本與帳戶原留印鑑至分行申請調整非約轉額度，每筆/每日新臺幣1~50萬、每月新臺幣1~100萬。自設限額須以萬元為單位。
# 此「非約定帳戶轉帳」限額計入CUBE網路銀行、CUBE App合併計算
# CUBE網路銀行及CUBE App之繳費、繳稅交易金額不計入此非約轉額度。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 目標儲蓄有什麼注意事項？
# Text Content: 目標儲蓄注意事項如下：
# 目標儲蓄限於網銀App設定，並於網銀/網銀App查詢。
# 每月執行目標儲蓄交易時，若當下您的約定轉帳或本人國泰帳戶互轉功能已關閉，非約定轉帳累計額度又超過單筆/日/月限額，該筆目標儲蓄交易將會失敗，建議您於目標儲蓄期間，請勿關閉約定轉帳或本人國泰帳戶互轉功能，避免執行轉帳時超過額度。
# 設定後將以最近可執行日(不含當日)作為第一次目標儲蓄交易日，若每月扣款日選擇的日期等於或小於當天日期，第一次交易日會是次月，若大於當日日期，第一次交易日會是當月。
# 目標儲蓄交易日及儲蓄結束日為非營業日、或無相對應日，或因不可抗力事由、或其他原因致使當日暫停營業，將以次營業日為轉帳日。所謂無相對應日以次營業日為轉帳日，如設定固定每月 31 日轉帳，因 2 月份無 31日，故會在次營業日才轉帳。
# 如欲取消目標儲蓄排程，最遲應於目標儲蓄交易日之前一日辦理。
# 若承作目標儲蓄之帳戶辦理結清，或停用約轉、非約轉功能，則原目標儲蓄（轉帳）交易同時取消。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 只要是智慧型裝置皆可使用交易認證碼嗎？
# Text Content: 用戶於CUBE App 申請交易認證碼時，須透過SIM驗證與簡訊OTP申請，系統將判別客戶留存手機是否與該手機上網SIM相同，若比對不相符時將無法啟用交易認證碼，會引導利用人臉辨識進行非約轉。無法透過SIM驗證交易認證碼之未成年、法人、和外國人客戶，將維持OTP申請流程並於24小時後啟用交易認證碼。
# 驗證前請關閉wifi，並利用行動上網連線。
# 支援電信商：服務僅提供中華電信、台灣大哥大、遠傳、台灣之星、亞太與ibon mobile統一超商電信客戶使用。
# 適用機型: 手機須可進行行動上網。
# CUBE App所支援之手機作業系統版本如下：支援iPhone iOS 13.0(含)以上手機版本；標準Google 官方公佈的支援裝置，Android OS 7.0(含)以上手機版本。
# *請使用系統未經破解的手機，並透過官方軟體商店下載CUBE  App及安裝防毒軟體，以降低交易風險及保護個人資訊安全。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 目標儲蓄扣款失敗的原因有哪些？
# Text Content: 若目標儲蓄有下列情形，交易將失敗：
# 執行目標儲蓄交易時，若當下您的約定轉帳或本人國泰帳戶互轉功能已關閉，非約定轉帳累計額度又超過單筆/日/月限額，該筆目標儲蓄交易將會失敗，建議您於目標儲蓄期間，請勿關閉約定轉帳或本人國泰帳戶互轉功能，避免執行轉帳時超過額度。
# 若承作目標儲蓄之母子帳戶辦理結清，或停用約轉、非約轉功能，則交易同時取消。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 如何下載存摺明細？
# Text Content: 點選 “更多”，進入 “帳戶”，點選 “匯出台外幣電子存摺”，設定欲匯出的帳戶與時間區間，匯出成功即可至您的電子信箱收取檔案。
# 點擊 “更多”後，選取“匯出台外幣電子存摺”
# 設定匯出帳戶 (台外幣) 與匯出時間區間
# 匯出成功即可至您的電子信箱收取檔案
# --------------------------------------------------
# Categories: 子帳戶
# Title: 可以設定幾筆目標儲蓄？
# Text Content: 單一子帳戶僅能設定一筆目標儲蓄排程。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 我如何調整非約定轉帳限額?
# Text Content: 您可持身分證正本與帳戶原留印鑑至分行申請調整非約轉額度，每筆/每日新臺幣1~50萬、每月新臺幣1~100萬。自設限額須以萬元為單位。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 如何查詢目標儲蓄進度？
# Text Content: 可於網路銀行App與網路銀行查詢目標儲蓄進度，查詢方式如下：
# 登入網銀App，點選臺幣總額，於子帳戶下方即會顯示目前儲蓄進度；若繼續點選子帳戶右方更多功能 >【查看目標儲蓄】也可查詢詳細資訊。
# 登入網銀，於帳戶總覽的子帳戶下方即會顯示目前儲蓄進度；若點選目標儲蓄進度條，將直接顯示目標儲蓄詳細資訊。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 甚麼人可以在CUBE App調整ATM提領限額? 可用甚麼驗證方式?
# Text Content: 成年且持有存款帳戶者，都可以在CUBE App透過人臉辨識或交易認證碼調整喔！ 若該手機有綁定人臉辨識或交易認證碼擇一可以當作驗證方式，若尚未申請也會引導用戶申請。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 目標儲蓄轉帳限額如何計算？
# Text Content: 目標儲蓄轉帳限額說明如下：
# 執行目標儲蓄設定時，將比照您於本行約定的轉帳方式，若您有開啟本人國泰帳戶互轉功能，或母帳戶有申請約定轉帳，則不需其他驗證工具即可設定完成。
# 若您未開啟上述功能，僅開啟非約定轉帳功能，則需使用交易認證碼或人臉驗證，方能設定目標儲蓄。
# 若您未開啟任何交易驗證工具，畫面將引導您開啟本人國泰帳戶互轉功能。
# 目標儲蓄轉帳時，也將比照您於本行約定的轉帳方式累計額度，建議您於目標儲蓄期間，請勿關閉約定轉帳或本人國泰帳戶互轉功能，避免執行轉帳時超過非約定轉帳額度而交易失敗。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: ATM提領限額調整後何時生效？我有多個帳戶，調整一次就好嗎?
# Text Content: 調整後立即生效。
# ATM提領限額是需要每個帳戶分別設定，若有多個帳戶請分別設定。
# --------------------------------------------------
# Categories: 子帳戶
# Title: 為什麼目標儲蓄金額跟我想設定的不一樣？
# Text Content: 目標儲蓄金額設定說明如下：
# 輸入期望存滿的金額以及期間後，將為您試算出平均每次扣款金額；
# 每次的儲蓄金額為：目標儲蓄總金額除以儲蓄期間，若無法除盡，則小數點第一位將無條件進位。
# ※儲蓄金額舉例：若目標儲蓄總金額輸入$100,000，儲蓄期間為12個月， $100,000/12=$8,333.33333…，則每月扣款金額將無條件進位為$8,334， 每月儲蓄$8,334存滿12個月後，目標儲蓄總金額將為$8,334*12=$100,008， 故將比您預計設定的十萬元來的多一些。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 我如何開啟數位外幣帳戶？
# Text Content: 進入外幣帳戶，點擊 “線上開戶”
# 點擊“我要開啟外幣帳戶”
#  閱讀帳戶約定條款並同意繼續
#  進行身分認證
# 填寫開戶資料與開戶目的
# 點擊“新增照片”
# 拍攝證件，確認無誤後上傳
# 確認證件資訊正確後點擊“確認”
#  確認填寫資料正確後點擊“確認”
#  完成外幣帳戶開戶申請，回外幣總覽
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳
# Title: 如何在CUBE App上使用敲匯議價功能?
# Text Content: 在分行敲匯後，CUBE App首頁外幣總額出現紅點提示
# 進入帳戶總覽頁點擊「敲匯優惠」
#  確認匯率議價頁資訊，選擇轉出轉入帳號
#  確認匯率議價頁資訊，確定換匯
# 確認交易成功，回外幣總覽
# --------------------------------------------------
# Categories: 帳務性問題, 臺外幣帳務與轉帳
# Title: 本人國泰帳戶互轉服務與約定帳號轉帳有甚麼不同?
# Text Content: 兩個轉帳的服務都可以讓您名下的國泰帳戶轉帳限額無上限。約定帳號需要至臨櫃開啟約定帳號轉出服務，並需至臨櫃或CUBE App逐筆設定帳號才可使用；但本服務於網路銀行設定開啟即可。
# --------------------------------------------------
# Categories: 帳務性問題, 臺外幣帳務與轉帳
# Title: 如果我已經設定過約定帳號轉出，也可以設定本人國泰帳戶互轉服務嗎?
# Text Content: 可以，您若已設定過約定帳號轉出的帳號，您亦可重複設定本人國泰帳戶互轉服務。
# --------------------------------------------------
# Categories: 帳務性問題, 臺外幣帳務與轉帳
# Title: 本人國泰帳戶互轉適用的帳戶包含哪些?
# Text Content: 包含您於本行名下的活期儲蓄存款帳戶、數位存款帳戶、KOKO存款帳戶等皆可相互轉帳，並無上限。但不包含私銀帳戶、聯名戶、籌備處、獨資戶、政治獻金戶、備償戶、全權委託戶等帳戶類別。
# --------------------------------------------------
# Categories: 帳務性問題, 臺外幣帳務與轉帳
# Title: 若要設定本人在國泰世華的所有帳號可以互轉，可以透過視訊服務完成嗎?
# Text Content: 無須進入視訊即可設定！您可以登入國泰世華CUBE網銀或CUBE App，自行設定本人國泰世華帳戶互轉。
# --------------------------------------------------
# Categories: 帳務性問題, 臺外幣帳務與轉帳
# Title: 如果我想取消本人國泰帳戶互轉服務，要如何設定?
# Text Content: 請登入
# CUBE網銀：點選臺幣存匯→轉帳服務→轉帳帳號設定→本人國泰世華帳戶互轉→點選停用。
# CUBE App：點選更多功能→點選交易設定→本人國泰世華帳戶互轉→點選取消設定。
# --------------------------------------------------
# Categories: 帳務性問題, 臺外幣帳務與轉帳
# Title: 如果我取消設定開啟本人國泰帳戶互轉，會影響到我約定帳號轉帳的功能嗎?
# Text Content: 不會，兩者功能不會相互影響。
# --------------------------------------------------
# Categories: 帳務性問題, 臺外幣帳務與轉帳
# Title: 請問我可以利用【帳戶互轉】服務，進行他行的本人帳戶設定嗎?
# Text Content: 本服務提供您設定在國泰世華開立的帳戶。若您需要設定他行的本人帳戶，可以設定約定轉入帳號、或開啟非約轉服務。
# --------------------------------------------------
# Categories: 手機/Email共用, 手機/Email共用
# Title: 為何我無法與他人共用手機門號/電子郵件？
# Text Content: 本行會透過您留存於本行的手機門號/Email，通知您與本行往來之所有個人帳務資訊與個人權益。請勿與其他用戶使用相同的手機門號/Email，以避免您的個人帳務隱私外洩並保障您的帳戶安全。
# 若您有家戶共用手機門號/電子郵件需求，請備妥您與手機門號/電子郵件共用者的關係證明文件正本(身分證、居留證、戶口名簿/戶籍謄本、法律判決書)，至CUBE網銀或分行臨櫃辦理手機/Email共用註記。目前僅開放申請特定關係對象共用手機門號/電子郵件，包含血親三等親內、姻親二等親內、法定代理人、或監護人之關係。一般客戶共用申請成功後，共用效期為期三年、未成年則至成年。
# *CUBE網銀申請路徑：[申請設定]→[資料異動]→[修改個人資料]→共用註記申請/進度查詢
# *血親三等親內、姻親二等親內關係說明如下:
# --------------------------------------------------
# Categories: 手機/Email共用, 手機/Email共用
# Title: 若有特定共用需求能與哪些人共用手機門號/電子郵件？如何申請？
# Text Content: 目前僅開放申請特定關係對象共用手機門號/電子郵件，包含血親三等親內、姻親二等親內、法定代理人、或監護人之關係。請確認共用對象符合資格，備妥關係證明文件正本(身分證、居留證、戶口名簿/戶籍謄本、法律判決書)，至CUBE網銀或分行臨櫃辦理，一般客戶共用申請成功後，共用效期為期三年、未成年則至成年。
# *CUBE網銀申請路徑：[申請設定]→[資料異動]→[修改個人資料]→共用註記申請/進度查詢
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 網路銀行包括哪些服務範圍 ? 提供哪些服務 ?
# Text Content: 網路銀行服務範圍包含您與本行所有往來的業務與產品，主要包含臺幣、外幣、信用卡、繳費繳稅、投資、貸款、保險、申請設定及個人權益等九大類。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我可以申請網路銀行嗎?
# Text Content: 只要您有本行帳戶、本行信用卡( 限正卡、不含商務卡)，即可申請網路銀行。
# *信用卡戶可於網路銀行查看信用卡相關帳務資訊。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 如何申請「用戶代號」及「網銀密碼」？
# Text Content: 本行成年存戶請用以下方法申請：
# 分行申請：持身分證正本與帳戶原留印鑑，親洽任一分行即可申請。
# ATM申請：持國泰世華銀行所發行之晶片金融卡，透過國泰世華銀行ATM申請。
# CUBE App申請_視訊客服：透過國泰世華CUBE  App，在登入頁面選擇【忘記代號/密碼】→ 選擇【視訊客服】進行簡訊OTP驗證及身分證資料驗證，即可進入視訊服務申請。
# 本行未成年存戶請偕同法定代理人雙方/監護人於營業時間親洽任一分行申請，並攜帶下列正本資料：
# 未成年人-【戶口名簿/戶籍謄本/身分證正本】+【第二身分證件】+【原留印鑑】 。
# 法定代理人雙方-【身分證正本】+【第二身分證件】。
# 單親法定代理人/監護人-【身分證正本】+【第二身分證件】+ 提供載明監護權歸屬的文件，如：戶口名簿或戶籍謄本或法院判決書/裁定書等文件正本。
# 如法定代理人一方不克前來，需另徵提【委託人身分證正本】+【第二身分證件】+【辦理存款業務同意書】 。
# 一旦申請或重設，須於指定時效內進行設定，始完成啟用流程，效期說明：密碼單為15日(須以密碼單內之指定用戶代號及網銀密碼登入CUBE網銀或CUBE App變更啟用)；簡訊連結為簡訊發送後72小時內(設定後始生效力)。
# 本行正卡卡友（不含商務卡）請用以下方法申請：
# CUBE  App、CUBE 網路銀行申請：於簡訊OTP驗證後自行設定用戶代號及網銀密碼。
# 本行智能客服：進入智能客服對話並選擇【信用卡戶】，輸入身分證字號並完成簡訊OTP驗證後，即可設定用戶代號及網銀密碼。
# 備註：信用卡理網銀碼服務範圍僅限信用卡相關查詢功能，若您同時為本行存款戶，欲使用帳務功能，請參閱存戶申請網銀密碼方式，體驗完整的數位理財服務。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 什麼是用戶代號和網銀密碼？登入網路銀行為何這麼麻煩？
# Text Content: 用戶代號與網銀密碼為您登入網路銀行的個人帳號，依《金融機構辦理電子銀行業務安全控管作業基準》，兩道加密是為確保您個人帳務機密，以防不法人士盜用。
# 登入網路銀行須先後輸入：
# 用戶代號 (6-12位英文與數字混合)
# 網銀密碼 (6-16位英文與數字混合)
# 溫馨提醒：
# 兩者規則皆為英文最少二位、數字最少一位、英文字大小寫視為不同；設定時請勿使用生日、電話、身分證字號、連續升降冪英數字、相同數字或具規則性排列等字串，以免被有心人士竄用。
# 為提高安全性，用戶代號與網銀密碼無法設定為相同。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 用戶代號或網銀密碼輸入錯誤致失效或忘記無法登入網路銀行怎麼辦？
# Text Content: 本行成年存戶請用以下方法申請重設：
# 分行申請：持身分證正本與帳戶原留印鑑，親洽任一分行即可申請。
# ATM申請：持國泰世華銀行所發行之晶片金融卡，透過國泰世華銀行ATM申請。
# CUBE  App申請_視訊客服：透過國泰世華CUBE  App，在登入頁面選擇【忘記代號/密碼】→ 選擇【視訊客服】進行簡訊OTP驗證及身分證資料驗證，即可進入視訊服務申請重設。
# CUBE  App申請_人臉辨識服務：如已註冊過人臉辨識，透過國泰世華CUBE  App，在登入頁面選擇【忘記代號/密碼】→ 選擇【人臉辨識】進行簡訊OTP驗證及人臉驗證，即可申請重設。
# 本行未成年存戶請偕同法定代理人雙方/監護人於營業時間親洽任一分行申請，並攜帶下列正本資料：
# 未成年人-【戶口名簿/戶籍謄本/身分證正本】+【第二身分證件】+【原留印鑑】 。
# 法定代理人雙方-【身分證正本】+【第二身分證件】。
# 單親法定代理人/監護人-【身分證正本】+【第二身分證件】+ 提供載明監護權歸屬的文件，如：戶口名簿或戶籍謄本或法院判決書/裁定書等文件正本。
# 如法定代理人一方不克前來，需另徵提【委託人身分證正本】+【第二身分證件】+【辦理存款業務同意書】 。
# 一旦申請或重設，須於指定時效內進行設定，始完成啟用流程，效期說明：密碼單為15日(須以密碼單內之指定用戶代號及網銀密碼登入CUBE網銀或CUBE App變更啟用)；簡訊連結為簡訊發送後72小時內(設定後始生效力)。
# 本行正卡卡友（不含商務卡）請用以下方法申請：
# CUBE  App、CUBE 網路銀行申請：於簡訊OTP驗證後自行設定用戶代號及網銀密碼。
# 本行智能客服：進入智能客服對話並選擇【信用卡戶】，輸入身分證字號並完成簡訊OTP驗證後，即可設定用戶代號及網銀密碼。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 為何無法於CUBE網銀進行非約轉交易？
# Text Content: 非約轉啟用狀態
# 狀況與應變
# 已啟用
# 您可能尚未申請「交易認證碼」或開啟「人臉辨識」，請下載國泰世華CUBE App，點選「交易設定」>「交易驗證方式」>啟用「交易認證碼」或「人臉辨識」。
# 未啟用
# 您可能是下列情況:
# 透過ATM申請網銀帳密，未啟用非約轉。
# 透過分行申辦網銀密碼時關閉非約定轉帳功能。
#             啟用方式:
# 請下載國泰世華CUBE App，點選「帳戶總覽」-「臺幣」頁面右上方進入「帳戶資訊」，在臺幣帳戶資訊頁可開啟非約定轉帳的設定，並啟用「交易認證碼」或「人臉辨識」。
# 請親洽任一分行或國泰世華ATM啟用非約定轉帳功能，並開啟交易認證碼或晶片金融卡已進行交易。
# --------------------------------------------------
# Categories: 申請及登入問題
# Title: 我的網路銀行能使用信用卡相關服務，如何進一步使用轉帳／基金申購等帳務服務？
# Text Content: 本行信用卡卡戶申請網路銀行，即能享有信用卡相關服務。若持有本行帳戶，欲進一步使用轉帳、帳務查詢、基金申購等其他服務，可透過下列方式升級：
# 分行申請：持身分證正本與帳戶原留印鑑，親洽任一分行即可申請。
# ATM申請：持國泰世華銀行所發行之晶片金融卡，透過國泰世華銀行ATM申請。
# CUBE App申請：透過視訊客服線上申請。
# --------------------------------------------------
# Categories: 申請及登入問題, 申請及登入問題
# Title: 什麼是登入兩步驟驗證？
# Text Content: 類似google、Facebook、IG的雙重驗證功能，有陌生裝置登入時需要進行第二道驗證(OTP/推播)來加強身分確認，保障帳戶安全性。
# 建議您可登入CUBE App/網銀啟用登入兩步驟驗證，未來陌生裝置登入時，除原先登入的帳號密碼/快速登入驗證方式外，需再進行OTP驗證後才能登入完成，多一重登入保護力喔。
# --------------------------------------------------
# Categories: 臺外幣帳務與轉帳, 帳務性問題
# Title: 如何使用CUBE App/網銀轉帳到其他帳戶？
# Text Content: 約定帳戶轉帳：若要設定約定轉帳帳號，請您攜帶身分證正本及原留印鑑親至任一分行設定，或透過CUBE  APP視訊約定服務設定。
# 非約定帳戶轉帳：若您已開啟非約定轉帳功能，並申請「人臉辨識」或「交易認證碼」，則可進行非約定帳戶轉帳。
# 本人本行帳戶轉帳：請您至CUBE 網銀「轉帳帳號設定」功能，選擇「本人國泰世華帳戶轉帳」，並透過簡訊OTP驗證完成設定，即可進行本人本行帳戶轉帳服務。
# --------------------------------------------------
# Categories: 帳務性問題
# Title: 為什麼沒辦法使用「約定帳戶轉帳」功能？
# Text Content: 可能有以下二種原因：
# 金額超過限額：約定轉帳單筆最高限額200萬元，單日轉帳限額300萬元。
# 已設定停用「約定轉帳」功能：若要重新開啟「約定轉帳」功能，需請您攜身分證印鑑至本行任一分行辦理，或透過本行CUBP App使用視訊服務申請。
# ...
# Text Content: 同一帳戶無卡提款資訊設定完成後尚未提款，無法再新增一筆（若需變更提款帳號或金額，請先取消原設定資料後再新增）；若非相同帳戶，則可以在不同手機提款通路再新增一筆提款資料。
# --------------------------------------------------
# Categories: 無卡提款
# Title: 我想使用手機/無卡提款服務，但是我有多個帳戶，每個帳號需要分別啟用並設定無卡/手機提款密碼嗎？
# Text Content: 是的，多個帳戶需分別設定無卡/手機提款密碼(該帳戶請先確認已開卡完成)，才可以選擇已開啟之帳戶進行無卡提款服務(含手機提款)；不同帳戶的無卡提款密碼須分別設定，但同一個帳戶不論使用手機提款，其無卡提款密碼皆為相同。
# --------------------------------------------------
# Categories: 無卡提款
# Title: 無卡提款交易設定完成後，發現金額或帳號設定錯誤，要如何修改？
# Text Content: 為確保客戶帳戶安全，無卡提款(含手機提款)資料設定完成後，若要修改，請先『取消』該筆資料後，再重新設定提款資料，取消後原提款資訊即無法再使用
# --------------------------------------------------
# Categories: 無卡提款
# Title: 【手機提款】我要如何在LINE或CUBE App上查詢設定的無卡提款資料？
# Text Content: LINE 官方帳號
# 可透過國泰世華LINE官方帳號主選單點選『ATM提款/優惠』→『查詢/取消 提款序號』，進行查詢；若為已逾期、已取消之設定超過24小時後，不提供查詢服務。
# CUBE App
# 可透過國泰世華CUBE App，點擊手機提款，即可查看手機提款的設定資訊。
# --------------------------------------------------
# Categories: 無卡提款
# Title: 進行手機/無卡提款交易時，無卡提款密碼忘記或被鎖怎麼辦？
# Text Content: 為確保您的帳戶安全，無卡提款密碼忘記或被鎖時(連續錯誤達3次)，可透過CUBE App手機提款重新設定，或持原帳戶之晶片金融卡至國泰世華銀行ATM重新設定後方可使用。
# --------------------------------------------------
# Categories: 無卡提款
# Title: 我不想使用手機/無卡提款服務，該如何中止使用？
# Text Content: 若需中止無卡提款(含手機提款)功能，可透過CUBE App手機提款設定功能關閉手機提款服務，或持原帳戶晶片金融卡至國泰世華銀行ATM進行中止。
# --------------------------------------------------
# Categories: 無卡提款
# Title: 我開啟無卡提款功能後，金融卡不見並掛失，是否還可以使用無卡提款？
# Text Content: 不行；當您的金融卡掛失後，將無法再對該帳戶進行無卡提款(含手機提款)功能，待重新開卡後才可使用。
# --------------------------------------------------
# Categories: 無卡提款
# Title: 同一個身分證號最多可以開啟多少個帳號的無卡提款功能？
# Text Content: 同一個身分證號最多可以開啟20組帳號的無卡提款(含手機提款)功能。
# --------------------------------------------------
# Categories: 無卡提款
# Title: 手機/無卡提款服務停用後，要如何重新再啟用？
# Text Content: 可透過CUBE App的手機提款設定功能，或持國泰世華銀行晶片金融卡，至國泰世華銀行ATM申請無卡提款功能，並選擇『停用後重新啟用』，設定完無卡提款密碼後即可再次使用。
# --------------------------------------------------
# Categories: 提款機
# Title: 如何操作ATM存/提款機?
# Text Content: 本行ATM已針對常用服務項目進行簡易分類呈現，您可參考以下交易流程：插入本行晶片金融卡 → 選擇服務項目 → 輸入金融卡密碼。
# --------------------------------------------------
# Categories: 提款機
# Title: 操作ATM時遇到錯誤訊息怎麼辦?
# Text Content: 您可透過
# ATM錯誤訊息代號
# 進行查詢。
# --------------------------------------------------
# Categories: 提款機
# Title: 哪裡可以找到ATM及補摺機?
# Text Content: 查詢本行ATM或補摺機設置點，請至本行官網
# 服務據點查詢
# 。
# --------------------------------------------------
# Categories: 提款機
# Title: ATM提款是否有任何額度限制?
# Text Content: 本行存提款機提款：每次限額10萬 ; 跨行提款：每次限額2萬，每日累積提領限額則依各發卡行規定，每次跨行提款手續費為5元。
# --------------------------------------------------
# Categories: 提款機
# Title: 為什麼ATM螢幕會顯示本國卡/外國卡?
# Text Content: 若您使用的金融卡含有信用卡功能，於ATM交易時僅顯示本國卡/外國卡、無顯示金融卡選項，表示ATM讀取不到晶片資料，可能因晶片毀損或髒汙情況，請用乾淨布先擦拭晶片或更換其它台ATM操作。
# --------------------------------------------------
# Categories: 提款機
# Title: 銀聯卡於國泰世華ATM提領有沒有任何金額限制?
# Text Content: 銀聯卡每筆提領限額為台幣2萬元，每日累積提領限額則依各發卡行規定。
# --------------------------------------------------
# Categories: 提款機
# Title: 台幣電子存單是否可以透過ATM開立?
# Text Content: 本行ATM可開立電子存單，起存金額為每筆新台幣1萬元整 。每日及每月累計最高限額，不得逾本行公告自動化通路轉存一般利率之新臺幣定期性存款限額。
# --------------------------------------------------
# Categories: 提款機
# Title: ATM是否可以無卡存款?
# Text Content: 本行具備存款功能之ATM，無需插卡，只要輸入本行活期性存款帳號，或綁定過的手機號碼即可進行現金存款。
# --------------------------------------------------
# Categories: 提款機
# Title: ATM存款多久會入帳?
# Text Content: 本行存款機存款，皆為即時入帳，可立即動用。
# --------------------------------------------------
# Categories: 提款機
# Title: ATM無卡存款有沒有任何限制?
# Text Content: 僅限存入國泰世華銀行帳號，存入帳戶每日限額3萬元。
# --------------------------------------------------
# Categories: 提款機
# Title: 存款機是否有存入的金額限制?
# Text Content: 無卡存款：僅限存入國泰帳號，存入帳戶每日限額3萬元，母帳戶與子帳戶單日限額合併計算。
# 有卡存款：
# (1) 使用國泰金融卡：存入本人帳戶無限額，存入他人帳戶每日限額3萬元。
# (2) 使用他行金融卡：依存入帳戶所屬銀行規定。
# --------------------------------------------------
# Categories: 提款機
# Title: 國外銀行金融卡能不能用國泰ATM提領?
# Text Content: 如您使用的外國銀行金融卡，屬VISA、MASTERCARD、PLUS、CIRRUS、AMERICAN EXPRESS、JCB、銀聯、財金公司所發行的卡，均可於國泰ATM提款。
# --------------------------------------------------
# Categories: 跨國提款
# Title: 如何開啟跨國提款功能？
# Text Content: 如需使用本行晶片金融卡 / 簽帳金融卡 / COMBO 信用卡跨國提款服務，出國前請先確認該金融卡已開啟跨國提款功能。
# 一、跨國提款功能查詢方式：
# 登入國泰世華銀行 CUBE 網銀，點選「申請設定」→「金融卡查詢 / 設定」→「金融卡跨國交易」，查看金融卡跨國交易功能狀態。
# 二、跨國提款功能啟用方式：
# 攜帶身分證與開戶印鑑至本行各地分行臨櫃辦理。
# 三、跨國提領方式：
# 依國外地區，可於貼有國際組織（／或／）標誌的 ATM 提款。插入與 ATM 標誌相同之卡片，輸入金融卡 4 位數字磁條提款密碼由您的國泰世華銀行帳戶提領當地貨幣。
# --------------------------------------------------
# Categories: 跨國提款
# Title: 跨國提款手續費收取方式為何？
# Text Content: 跨國提款手續費收取方式請參閱跨提轉帳費用說明。
# --------------------------------------------------
# Categories: 跨國提款
# Title: 跨國提款交易限額為多少？
# Text Content: 跨國 ATM 提款每次交易最高限額為等值新臺幣 2 萬元之當地貨幣，每日交易限額請登入 CUBE App 「帳務總覽」→ 點選「臺幣總額」 → 右上角「帳務資訊」依您所提領之帳號查詢，惟每人每日最高累積提領外幣金額以等值一萬美元為限。（以台灣時間為準，不分平假日）
# ※ 持卡人在國外使用國際金融卡時，除依本行約定事項辦理外，另須遵循國外服務行自動櫃員機等設備之相關提款規定。
# --------------------------------------------------
# Categories: Unknown Category
# Title: 兌換外幣現鈔的手續費怎麼計算?
# Text Content: 本行兌換外幣現鈔費用依兌換方式分別收取兌換手續費及匯差手續費，說明如下：
# *兌換手續費收費標準：
# 新臺幣換外幣現鈔：
# (1) 以現鈔兌換：每筆新臺幣200元
# (2) 自帳戶扣款：每筆新臺幣100元
# 外幣現鈔換新臺幣：
# (1) 兌換現鈔：每筆新臺幣200元
# (2) 轉入帳戶：每筆新臺幣100元
# *匯差手續費收費標準：
# 從本行的外匯存款中提領同幣別之外幣現鈔，需要負擔賣出即期匯率與賣出現鈔匯率之差額，最低NT$100。
# 外幣現鈔存入本行同幣別外匯存款，需要負擔買入即期匯率與買入現鈔匯率之差額，最低NT$100。
# ※ ‌  查詢外幣匯率
# ※可兌換外幣現鈔：美金、歐元、日圓、港幣、人民幣等五種。
# ※ ‌  兌換外幣現鈔手續費用收取方式。
# --------------------------------------------------
# Categories: Unknown Category
# Title: 人民幣定存交易限額為何?
# Text Content: 本行每筆最低交易金額為等值美金一千元整，由其他幣別轉定存為人民幣，交易限額為每人每日人民幣二萬元（各通路交易合併計算）。
# --------------------------------------------------
# Categories: Unknown Category
# Title: 是否有提供韓幣兌換?
# Text Content: 本行未提供韓圜（KRW）兌換。
# --------------------------------------------------
# Categories: Unknown Category
# Title: OBU跟DBU差別在哪裡?
# Text Content: OBU 業務與DBU外匯指定銀行所承作之業務並無差異，主要差別在於 OBU 業務依規定不得涉及新台幣，且服務對象為境外個人、法人、政府機關、金融機構。
# --------------------------------------------------
# Categories: Unknown Category
# Title: 我需要符合甚麼資格才能使用CUBE App服務？ What are the requirements for using services available on the CUBE App?
# Text Content: 只要您擁有本行有效帳戶或信用卡，並申請「網銀密碼」，即可使用CUBE App服務。
# To use services on the CUBE App, all you need to prepare is a valid CUB account/CUB credit card and an online banking password.
# --------------------------------------------------
# Categories: Unknown Category
# Title: 我要如何申請網銀密碼？ (外國人) How do I set up an online banking password? (For foreigners)
# Text Content: 持有本行存款帳戶外國客戶請攜帶開戶時的身分證件及原留印鑑至分行。
# 持有本行信用卡外國客戶持有本行信用卡正卡者，可透過CUBE網銀線上申辦網銀密碼，操作流程請參考此。
# DepositorsPlease bring the identification documents and registered specimen seal you used when opening your account to any CUB branch.
# CardholdersIf you have the primary card of a credit card issued by the Bank, you can set up a password for your online banking account using CUBE Online Banking. Click here to learn how to set up the password.
# --------------------------------------------------
# Categories: Unknown Category
# Title: 我忘記「網銀密碼」或「用戶代號」，該如何重新申請？(外國人) I forgot my online banking password or user code. How do I reapply? (For foreigners)
# Text Content: 外國客戶請攜帶開戶時的身分證件及原留印鑑至分行重新申請。
# Please bring the identification documents and registered specimen seal you used when opening your account to any CUB branch.
# --------------------------------------------------
# Categories: Unknown Category
# Title: 如果陌生人使用了我的手機門號該怎麼辦？(外國人) What should I do if someone else has already used my mobile number? (For foreigners)
# Text Content: 請您依照流程指引完成 Mobile ID行動身分識別服務，驗證為本人門號後，即可繼續本行的相關服務申請。您可攜帶近三個月內的電信帳單等門號證明文件至分行臨櫃辦理，若您使用公司配發門號，除近三個月的電信帳單外，需額外備妥在職證明文件。
# Please follow the procedure to complete the Mobile ID authentication. After we verify your mobile number, you may proceed with your application at the Bank. You may instead provide authentication documents, such as your phone bill within the last three months, and apply for services over the counter. If your mobile number is provided by your employer, you should also prepare an employment verification letter.
# --------------------------------------------------
# Categories: Unknown Category
# Title: 外國人要如何申辦信用卡？  I’m a foreigner. How do I apply for a credit card?
# Text Content: 外國人申辦信用卡資格說明，請至外籍人士辦卡專區。
# For more information about credit card application, visit Card Application Procedures for Foreign Nationals.
# --------------------------------------------------
# Categories: Unknown Category
# Title: 如何申請帳戶自動扣繳本行信用卡費？ 何時會生效？ How do I apply for credit card autopay? When will it be activated?
# Text Content: 從銀行帳戶自動扣繳信用卡費辦理方式：設定本行本人帳戶扣款：本人持身分證件及帳戶原留印鑑至本行任一分行辦理。
# 若信用卡自動扣繳已生效，帳單會有清楚提示；或登入CUBE網銀查詢。
# Setting an auto debit instruction for your credit card payments:
# Auto debit from your CUB account: You will need to bring identification documents and registered specimen seal to any CUB branch to set up autopay.
# If autopay is activated, you will find the information on your bank statement. You can also check the activation status by logging into your Online Banking CUBE.
# --------------------------------------------------
# Categories: Unknown Category
# Title: 國外銀行金融卡能不能用國泰ATM提領？ Can I make withdrawals at CUB’s ATMs using ATM cards issued by foreign banks?
# Text Content: 如您使用的外國銀行金融卡，屬VISA、MASTERCARD、PLUS、CIRRUS、AMERICAN EXPRESS、JCB、銀聯、財金公司所發行的卡，均可於國泰ATM提款。
# Yes, you can. Our ATMs accept debit cards issued by VISA, MasterCard, PLUS, Cirrus, American Express, JCB, UnionPay, and FISC.
# --------------------------------------------------
# Categories: 申請及查詢
# Title: 如何申辦綜合對帳單？要準備什麼文件？
# Text Content: 您可透過網路銀行、臨櫃或客服專線申辦綜合對帳單。→申辦綜合對帳單
#         網路銀行：請您登入後，至「申請設定→對帳單/通知單設定」頁面→點選「確定」→於「對帳單/通知單服務申請及約定條款」頁面勾選「我同意」→點選「下一步」即完成申請。
# 臨櫃：您可攜帶身分證及原留印鑑至各分行申請。→查詢分行據點
# 客服專線：您可撥打0800-818-001或(02)2383-1000，按1→9接專人，於線上通過語音密碼驗證後即可申請。
# --------------------------------------------------
# Categories: 申請及查詢
# Title: 使用綜合對帳單服務需要具備什麼？
# Text Content: 申辦綜合對帳單後，您每月會收到Email通知，寄發至您留存於本行之電子郵件信箱，並透過網路銀行查詢帳單。故您需具備：
# 有效存戶網銀密碼及用戶代號
# 於本行留存正確的電子郵件信箱
# --------------------------------------------------
# Categories: 申請及查詢
# Title: 手機可以申辦或查詢綜合對帳單嗎？
# Text Content: 可以。使用手機、平板或電腦只要透過瀏覽器登入網路銀行(網頁版)，都可以申辦或查詢綜合對帳單。(APP版行動銀行則尚未開放綜合對帳單服務)→申辦綜合對帳單
# --------------------------------------------------
# Categories: 申請及查詢
# Title: 申辦成功後，何時可收到綜合對帳單？
# Text Content: 當月申辦成功後，次月起可收到綜合對帳單Email通知，並透過網路銀行查詢帳單。
# --------------------------------------------------
# Categories: 申請及查詢
# Title: 我已經成功申辦綜合對帳單，為何查詢帳單後顯示「當月無資料」？
# Text Content: 「帳單年月」選單固定列示12期，您可查得啟用綜合對帳單服務後之期數，若選擇尚未啟用服務時之期數，則會顯示「當月無資料」。
# --------------------------------------------------
# Categories: 申請及查詢
# Title: 如果我持有國泰世華銀行的信用卡，申辦綜合對帳單後，銀行還會寄信用卡對帳單給我嗎？
# Text Content: 會。因綜合對帳單並未包含信用卡對帳單，兩者係分別寄送。故申辦綜合對帳單後，您的信用卡對帳單仍會依最終的設定狀態寄送電子或紙本對帳單予您。
# --------------------------------------------------
# Categories: 申請及查詢
# Title: 如果我在國泰世華銀行有理財往來，申辦綜合對帳單後，銀行還會寄理財對帳單給我嗎？
# Text Content: 不會。成功申辦綜合對帳單後，次月起開始改寄綜合對帳單通知予您，原本的理財對帳單則不再寄送。
# --------------------------------------------------
# Categories: 帳單內容
# Title: 綜合對帳單跟原來的對帳單有什麼不同？包含哪些項目？
# Text Content: 將原本個別寄送的對帳單，整合成一份，增加帳戶總覽之圖表分析。統一為Email通知，並可隨時透過網路銀行查詢。→查詢綜合對帳單
# 綜合對帳單已整合存款、理財、貸款、保險的帳務資訊，不含信用卡對帳單。
# --------------------------------------------------
# Categories: 帳單內容
# Title: 綜合對帳單要如何閱讀？
# Text Content: 帳單內設有快速連結，點選四大頁籤或放大鏡圖示，可直接跳轉至該單元或相關明細。您可利用快速連結功能找到您想要閱覽的內容。
# 帳戶總覽：資產負債總覽圖表分析
# 投資概況：理財產品庫存狀況
# 持有明細：存款、貸款、保險庫存狀況
# 交易明細：各產品交易明細
# --------------------------------------------------
# Categories: 帳單內容
# Title: 綜合對帳單是電子對帳單？還是紙本對帳單？
# Text Content: 綜合對帳單是電子對帳單，不寄送紙本帳單。申辦綜合對帳單後，您每月會收到Email通知，寄發至您留存於本行之電子郵件信箱，並透過網路銀行查詢帳單。→查詢綜合對帳單
# --------------------------------------------------
# Categories: 其他
# Title: 綜合對帳單是否可申請補發？
# Text Content: 可以。您可撥打客服專線0800-818-001或(02)2383-1000，按1→9接專人，於線上通過語音密碼驗證後，可為您補發至多近12期帳單通知。您亦可自行登入網路銀行查詢綜合對帳單，至多能查詢近12期帳單。→查詢綜合對帳單
# --------------------------------------------------
# Categories: 其他
# Title: 我可以申請補發或查詢一年以前的綜合對帳單嗎？
# Text Content: 不可以。您申請成功後次月開始製發您的首期綜合對帳單，於系統中至多保留近12期帳單。您可於每月自行下載綜合對帳單儲存於您的裝置內，即可自行永久保存。並提醒您務必妥善保管您的對帳單。
# --------------------------------------------------
# Categories: Unknown Category
# Title: 什麼是電子郵件數位簽章？
# Text Content: 數位簽章（digital signature）是一種利用計算機科學的技術，透過安全的加解密機制將電子文件進行數位簽章保護，除了可據以辨識寄件者身份外，也可確保傳送訊息內容的安全性與完整性。國泰世華銀行已逐步將寄送給客戶之電子郵件導入數位簽章技術，以供客戶辨識電子郵件為本行所寄出，且電子郵件在傳送過程中沒有遭到竄改，讓您開啟電子郵件更安心。如何確認您的郵件是否有數位簽章，可參考「Q3 電子郵件中的「smime」附件檔是什麼？」之說明內容。
# --------------------------------------------------
# Categories: Unknown Category
# Title: 無法正常顯示已簽章之電子郵件圖片內容
# Text Content: 為提高電子郵件安全性與本行客戶權益，本行將於外寄之電子郵件逐步導入數位簽章，以確保內容未被偽冒、竄改，並保持其完整性；惟使用者可能因設定關係而無法正常顯示郵件中之圖片，再請依附件中之步驟進行設定即可。
# 「無法正常顯示已簽章之電子郵件圖片內容 - 操作步驟」
# --------------------------------------------------
# Categories: Unknown Category
# Title: 電子郵件中的「smime或smime.p7s」的附件檔是什麼？
# Text Content: 如果您使用Gmail或Outlook收信，系統會自動驗證此數位簽章是否有效。
# 部分收信軟體（例如Yahoo Mail）因不支援此功能，會將數位簽章以名為「smime或smime.p7s」之附件呈現；此附件雖無法正常開啟，但並不會影響到原信件內容與您的權益。
# 請點選「「如何識別電子郵件數位簽章」」了解數位簽章於各平台之呈現方式。
# --------------------------------------------------
# Categories: Unknown Category
# Title: 收到含有數位簽章的電子郵件發生亂碼無法閱讀
# Text Content: 如果您是使用 Windows Live Mail 收發郵件，由於此軟體預設使用Big5編碼開啟信件，本行對外所發送電子郵件是使用UTF-8編碼，因此會有編碼不一致導致亂碼的情形發生。
# 請再依附件「解決Windows Live Mail郵件亂碼方法」操作步驟進行設定即可。
# 微軟已於 2017 年 1 月 10 日停止支援 Windows Live Mail 相關軟體功能及安全性更新，也提醒客戶可考慮使用其它工具(如 Outlook、Gmail..等)來收發電子郵件。
# --------------------------------------------------
# Categories: Unknown Category
# Title: 為何國泰世華銀行最近都有非營業單位(分行)的電話進行銀行業務通知事項?
# Text Content: 國泰世華銀行現行部份業務通知作業由下列各作業中心進行通知，謹提供各作業中心電話及地址如下：
# *存匯作業中心
# 作業中心名稱
# 電話
# 地址
#  北區存匯作業中心
#  02-23887780
#  台北市信陽街18號四樓、五樓、六樓
#  中區存匯作業中心
#  04-22252777
#  台中市西區自由路一段148號五樓
#  南區存匯作業中心
# 07-2270699
#  高雄市新興區中正三路55號十樓
#  外匯作業中心
#  02-23163555
# 台北市中正區館前路65號三樓
# *授信作業中心
# 作業中心名稱
# 電話
# 地址
#  北區授信作業中心
# 02-23110609
# 02-21910086
# 02-23125608
#  台北市中正區館前路65號四樓、六樓
# 中區授信作業中心
# 04-22107188
# 04-22107198
#  台中市西區自由路一段148號四樓、十樓
#  南區授信作業中心
# 07-2280988
# 高雄市新興區中正三路55號四樓
#  貸款中心
#  02-89797768
#  台北市松山區光復南路35號十樓
#  國際金融作業中心
#  02-23163555
#  台北市中正區館前路65號三樓
#  進出口作業中心
# 02-23125608
#  02-21910086
#  台北市中正區館前路65號六樓
# --------------------------------------------------
# Categories: 合作範圍
# Title: 與集保合作的開放銀行是什麼業務?
# Text Content: 客戶可於集保e手掌握APP內，查詢近三個月的本行證券交割帳戶的餘額和交易明細。
# --------------------------------------------------
# Categories: 合作範圍
# Title: 哪些國泰世華銀行帳戶可連結集保e手掌握?
# Text Content: 目前本行開放國泰證券所有分公司的證券交割帳戶可連結集保e手掌握。
# --------------------------------------------------
# Categories: 合作範圍
# Title: 使用身分限制?
# Text Content: 具備國泰證券的證券交割帳戶之本國國籍成年自然人。
# --------------------------------------------------
# Categories: 連結帳戶
# Title: 如何才能於集保e手掌握內連結本行的證券交割戶資訊?
# Text Content: 首次連結: 需登入集保e手掌握後，點選集保e手掌握「我的資產」最上方之連結銀行卡片，並於國泰世華CUBE App進行身分確認與同意授權後，即可成功連結本行帳戶。
# 後續連結: 首次連結成功後進入銀行資產>查看/管理 銀行資訊，點選右上方的「+」，即可辦理連結銀行。
# --------------------------------------------------
# Categories: 連結帳戶
# Title: 只能從集保e手掌握入口辦理連結本行帳戶嗎?
# Text Content: 是。
# --------------------------------------------------
# Categories: 連結帳戶
# Title: 從集保e手掌握引導至本行CUBE App進行身分確認失敗，可能有哪些原因?
# Text Content: (1) 請確認本行CUBE App是否是最新的版本。
# (2) 網銀帳號或密碼輸入錯誤 (信用卡網銀密碼不可使用)。
# (3) 認證授權服務一日上限3次，超過驗證次數上限，需等隔日再重新進行認證授權。
# --------------------------------------------------
# Categories: 連結帳戶
# Title: 連結國泰證券交割帳戶至集保e手掌握是否有時間限制？重新連結需要再次進行身分確認嗎？
# Text Content: 因應主管機關規定，透過集保e手掌握連結銀行每次授權連結以三個月為限，客戶可於三個月內登入集保e手掌握無限次數查詢銀行資料。如超過三個月，客戶需重新連結銀行再次進行認證授權才可繼續查詢銀行資料 。
# --------------------------------------------------
# Categories: 查詢帳戶資訊
# Title: 可於集保e手掌握查詢本行帳戶資訊的資料範圍和有效時間?
# Text Content: 客戶可於集保e手掌握APP內，查詢本行近三個月國泰證券交割帳戶的餘額和交易明細。
# --------------------------------------------------
# Categories: 查詢帳戶資訊
# Title: 如何於集保e手掌握內查詢本行的帳戶資料?
# Text Content: 登入集保e手掌握後在 我的資產>銀行資產>查看/管理 銀行資訊 銀行資訊透過銀行資產，點選「查看/管理 銀行資訊」，即可查詢所連結的銀行帳戶細節進行查詢，包含銀行別、帳戶類型、銀行帳號(僅呈現後4碼)、幣別及帳戶餘額。
# --------------------------------------------------
# Categories: 查詢帳戶資訊
# Title: 集保e手掌握會不會保留本行客戶的銀行帳務資料?
# Text Content: 不會保留。只要客戶登出集保e手掌握或閒置超過10分鐘後，銀行帳戶資料即刪除，不會留存於系統內。
# --------------------------------------------------
# Categories: 取消連結帳戶、終止授權
# Title: 如何於集保e手掌握APP內取消與銀行的帳戶連結?
# Text Content: 我的資產>銀行資產>查看/管理 銀行資訊>銀行帳戶>設定>取消銀行連結進入「查看/管理 銀行資訊」，點選任一銀行右上角之「齒輪圖示」，螢幕捲到最下方點選「取消銀行連結」，確認後即可取消銀行連結。
# --------------------------------------------------
# Categories: 取消連結帳戶、終止授權
# Title: 如何於國泰世華CUBE App內終止於集保e手掌握的帳戶連結授權?
# Text Content: 需登入本行CUBE App後，至設定>授權驗證管理> 臺灣集中保管結算所> 取消授權，確認後即可 終止於集保e手掌握的帳戶連結授權。
# --------------------------------------------------
# Categories: 通知信
# Title: 何時會收到通知信?
# Text Content: 每次進行連結帳戶的認證授權或終止授權，都會收到本行發出的即時通知信。
# 每個月2號本行會寄送彙整客戶於第三方服務平台進行開放銀行認證授權、終止授權和查詢資料的通知信。
# --------------------------------------------------
# Categories: 集保e手掌握客服資訊
# Title: 集保e手掌握的客服專線或email信箱
# Text Content: (1) 集保e手掌握客服專線(週一至週五08:30〜17:30)：(02)2719-5805 分機200、210、220
# (2) 意見反應信箱：epassbook.service@tdcc.com.tw
# --------------------------------------------------
# Categories: 集保e手掌握客服資訊
# Title: 有關集保e手掌握APP內的相關問題，可於哪裡找到更多資訊?
# Text Content: 集保e手掌握推廣網頁：http://epassbook.tdcc.com.tw
# --------------------------------------------------
